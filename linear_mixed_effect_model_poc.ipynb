# %%
import statsmodels.api as sm

import statsmodels.formula.api as smf
import pandas as pd

# %%
data = sm.datasets.get_rdataset("dietox", "geepack").data
print(data)
# md = smf.mixedlm("Weight ~ Time", data, groups=data["Pig"])

# mdf = md.fit()

# print(mdf.summary())
# Out:
#         Weight        Feed  Time   Pig  Evit  Cu  Litter
# 0     26.50000         NaN     1  4601     1   1       1
# 1     27.59999    5.200005     2  4601     1   1       1
# 2     36.50000   17.600000     3  4601     1   1       1
# 3     40.29999   28.500000     4  4601     1   1       1
# 4     49.09998   45.200001     5  4601     1   1       1
# ..         ...         ...   ...   ...   ...  ..     ...
# 856   73.19995   83.800003     8  8442     1   3      24
# 857   81.69995   99.800003     9  8442     1   3      24
# 858   90.29999  115.200001    10  8442     1   3      24
# 859   96.00000  133.200001    11  8442     1   3      24
# 860  103.50000  151.400002    12  8442     1   3      24
#
# [861 rows x 7 columns]
# /home/abhijit/anaconda3/envs/tenv/lib/python3.6/site-packages/statsmodels/datasets/utils.py:192: FutureWarning: `item` has been deprecated and will be removed in a future version
#   return dataset_meta["Title"].item()

# %%
df = pd.read_csv('./projects/hierarchical_quicknat/reports/hierarchical_quicknat_KORA_v2/KORA/10_1571905560.9377904_concat_report_final.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'volume_id', '0_spleen', '1_spleen', '2_spleen',
#        '3_spleen', '4_spleen', '5_spleen', '6_spleen', '7_spleen', '8_spleen',
#        '9_spleen', '0_liver', '1_liver', '2_liver', '3_liver', '4_liver',
#        '5_liver', '6_liver', '7_liver', '8_liver', '9_liver', 'seg_spleen',
#        'seg_liver', 'Unnamed: 0.1', 'age', 'alcohol-g/day',
#        'blood-pressure-diastolic', 'blood-pressure-systolic', 'bmi-numeric',
#        'bmi-who', 'cholesterol-hdl', 'cholesterol-ldl', 'cholesterol-total',
#        'diabetes_status', 'hba1c-mmol/mol', 'hba1c-percentage', 'height',
#        'hypertension', 'meds-antidiabetic', 'meds-antihypertensive',
#        'meds-incretin-mimetics', 'meds-insulin-therapy',
#        'meds-lipoprotein-lowering', 'meds-oral-antidiabetic',
#        'mri-liver-fat-artifacts', 'mri-liver-fat-lobus-dexter',
#        'mri-liver-fat-lobus-sinister', 'mri-liver-fat-portal-vein',
#        'mrt-image-id', 'sex', 'smoker', 'smoking-packages', 'triglyceride',
#        'weight', 'smoker_former', 'smoker_irregular', 'smoker_non-smoker',
#        'smoker_regular', 'bmi-who_normal', 'bmi-who_obesity class I',
#        'bmi-who_obesity class II', 'bmi-who_obesity class III',
#        'bmi-who_pre-obisety', 'project', 'dataset', 'model_name', 'samples',
#        'sncc', 'ged', 'iou_spleen', 'iou_liver', 'iou_mean', 'dice_spleen',
#        'dice_liver', 'dice_mean', 'surface_distance_prtogt_spleen',
#        'surface_distance_prtogt_liver', 'surface_distance_prtogt_mean',
#        'surface_distance_gttopr_spleen', 'surface_distance_gttopr_liver',
#        'surface_distance_gttopr_mean', 'surface_distance_avg_spleen',
#        'surface_distance_avg_liver', 'surface_distance_avg_mean'],
#       dtype='object')

# %%
cols = ['0_liver', '1_liver', '2_liver', '3_liver', '4_liver',
       '5_liver', '6_liver', '7_liver', '8_liver', '9_liver', 'Unnamed: 0', 'volume_id', 'seg_spleen',
       'seg_liver', 'Unnamed: 0.1', 'age', 'alcohol-g/day',
       'blood-pressure-diastolic', 'blood-pressure-systolic', 'bmi-numeric',
       'bmi-who', 'cholesterol-hdl', 'cholesterol-ldl', 'cholesterol-total',
       'diabetes_status', 'hba1c-mmol/mol', 'hba1c-percentage', 'height',
       'hypertension', 'meds-antidiabetic', 'meds-antihypertensive',
       'meds-incretin-mimetics', 'meds-insulin-therapy',
       'meds-lipoprotein-lowering', 'meds-oral-antidiabetic',
       'mri-liver-fat-artifacts', 'mri-liver-fat-lobus-dexter',
       'mri-liver-fat-lobus-sinister', 'mri-liver-fat-portal-vein',
       'mrt-image-id', 'sex', 'smoker', 'smoking-packages', 'triglyceride',
       'weight', 'smoker_former', 'smoker_irregular', 'smoker_non-smoker',
       'smoker_regular', 'bmi-who_normal', 'bmi-who_obesity class I',
       'bmi-who_obesity class II', 'bmi-who_obesity class III',
       'bmi-who_pre-obisety', 'project', 'dataset', 'model_name', 'samples',
       'sncc', 'ged', 'iou_spleen', 'iou_liver', 'iou_mean', 'dice_spleen',
       'dice_liver', 'dice_mean', 'surface_distance_prtogt_spleen',
       'surface_distance_prtogt_liver', 'surface_distance_prtogt_mean',
       'surface_distance_gttopr_spleen', 'surface_distance_gttopr_liver',
       'surface_distance_gttopr_mean', 'surface_distance_avg_spleen',
       'surface_distance_avg_liver', 'surface_distance_avg_mean']

to_transpose = [ '0_spleen', '1_spleen', '2_spleen',
       '3_spleen', '4_spleen', '5_spleen', '6_spleen', '7_spleen', '8_spleen',
       '9_spleen']
df = df.melt(id_vars=cols, 
        value_vars=to_transpose, 
        value_name="spleen_counts")

# %%
df.to_csv('tilted_spleen_counts.csv')

# %%
df.transpose().head(2000)
# Out:
#                                  0         1         2         3         4     \
# 0_liver                        107825    169591    106191    108813    150502
# 1_liver                        107890    169568    106214    108787    150490
# 2_liver                        107925    169594    106183    108851    150476
# 3_liver                        107865    169564    106215    108834    150442
# 4_liver                        107909    169553    106197    108866    150549
# ...                               ...       ...       ...       ...       ...
# surface_distance_avg_spleen  0.930961  0.910439  0.192045  0.873524  0.928819
# surface_distance_avg_liver   0.841623  0.833625  0.211413  0.895364  0.861962
# surface_distance_avg_mean    0.886292  0.872032  0.201729  0.884444  0.895391
# variable                     0_spleen  0_spleen  0_spleen  0_spleen  0_spleen
# spleen_counts                   12649     20359      6891     16244     17916
#
#                                  5         6         7         8         9     \
# 0_liver                        143931    157734    114588    264050    109340
# 1_liver                        143957    157780    114625    264082    109360
# 2_liver                        143963    157765    114641    264311    109338
# 3_liver                        143974    157786    114590    264473    109334
# 4_liver                        144009    157804    114669    264061    109324
# ...                               ...       ...       ...       ...       ...
# surface_distance_avg_spleen  0.969144  0.967801  0.954361  0.856191  0.996208
# surface_distance_avg_liver   0.917102   0.90693   0.87801  0.794559  0.955133
# surface_distance_avg_mean    0.943123  0.937366  0.916185  0.825375   0.97567
# variable                     0_spleen  0_spleen  0_spleen  0_spleen  0_spleen
# spleen_counts                   17363     15324     12726     17146     21784
#
#                              ...      1520      1521      1522      1523  \
# 0_liver                      ...    147807    156485    116863    132042
# 1_liver                      ...    147791    156536    116849    132023
# 2_liver                      ...    147767    156501    116852    132000
# 3_liver                      ...    147816    156526    116893    131967
# 4_liver                      ...    147807    156503    116887    132090
# ...                          ...       ...       ...       ...       ...
# surface_distance_avg_spleen  ...  0.959974  0.990095  0.923648  0.977981
# surface_distance_avg_liver   ...  0.915286  0.913647  0.907703  0.864647
# surface_distance_avg_mean    ...   0.93763  0.951871  0.915675  0.921314
# variable                     ...  9_spleen  9_spleen  9_spleen  9_spleen
# spleen_counts                ...     19098     18919     10370     14026
#
#                                  1524      1525      1526      1527      1528  \
# 0_liver                        171511    109150    153747    109718    177418
# 1_liver                        171463    109137    153764    109816    177472
# 2_liver                        171449    109133    153617    109742    177374
# 3_liver                        171471    109137    153809    109645    177370
# 4_liver                        171472    109143    153747    109690    177390
# ...                               ...       ...       ...       ...       ...
# surface_distance_avg_spleen  0.976312   0.99289  0.843266  0.911044  0.892546
# surface_distance_avg_liver   0.884411  0.920835  0.827109  0.836998  0.805804
# surface_distance_avg_mean    0.930361  0.956862  0.835187  0.874021  0.849175
# variable                     9_spleen  9_spleen  9_spleen  9_spleen  9_spleen
# spleen_counts                   12079     10613     20965     16631     14579
#
#                                  1529
# 0_liver                        107689
# 1_liver                        107736
# 2_liver                        107642
# 3_liver                        107701
# 4_liver                        107670
# ...                               ...
# surface_distance_avg_spleen  0.898031
# surface_distance_avg_liver   0.828491
# surface_distance_avg_mean    0.863261
# variable                     9_spleen
# spleen_counts                   23532
#
# [77 rows x 1530 columns]

# %%
df=df.fillna(0)


md = smf.mixedlm("diabetes_status ~ spleen_counts", df, groups=df["bmi-who"])

mdf = md.fit()

print(mdf.summary())
# Out:
#             Mixed Linear Model Regression Results
# =============================================================
# Model:            MixedLM Dependent Variable: diabetes_status
# No. Observations: 1530    Method:             REML
# No. Groups:       5       Scale:              0.4092
# Min. group size:  70      Likelihood:         -1510.7294
# Max. group size:  650     Converged:          Yes
# Mean group size:  306.0
# --------------------------------------------------------------
#                Coef.   Std.Err.    z     P>|z|  [0.025  0.975]
# --------------------------------------------------------------
# Intercept       0.741     0.214   3.467  0.001   0.322   1.160
# spleen_counts  -0.000     0.000  -0.260  0.795  -0.000   0.000
# Group Var       0.214     0.241
# =============================================================

# %%
mdf.resid
# Out:
# 0      -8.189541e-06
# 1      -7.509012e-06
# 2       9.912524e-07
# 3      -1.385631e-06
# 4       3.169971e-06
#             ...
# 1525   -8.168525e-06
# 1526   -8.275381e-06
# 1527   -3.669965e-06
# 1528    1.269974e-05
# 1529   -2.220972e-06
# Length: 1530, dtype: float64

# %%
md = smf.mixedlm("diabetes_status ~ spleen_counts", df, groups=df["volume_id"])

mdf = md.fit()

print(mdf.summary())
# Out:
#             Mixed Linear Model Regression Results
# =============================================================
# Model:            MixedLM Dependent Variable: diabetes_status
# No. Observations: 1530    Method:             REML
# No. Groups:       153     Scale:              0.0000
# Min. group size:  10      Likelihood:         16032.5316
# Max. group size:  10      Converged:          Yes
# Mean group size:  10.0
# --------------------------------------------------------------
#                 Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# --------------------------------------------------------------
# Intercept       0.471     0.018  26.080  0.000   0.435   0.506
# spleen_counts   0.000     0.000   0.004  0.996  -0.000   0.000
# Group Var       0.050  1022.428
# =============================================================

# %%
mdf.resid
# Out:
# 0      -8.189541e-06
# 1      -7.509012e-06
# 2       9.912524e-07
# 3      -1.385631e-06
# 4       3.169971e-06
#             ...
# 1525   -8.168525e-06
# 1526   -8.275381e-06
# 1527   -3.669965e-06
# 1528    1.269974e-05
# 1529   -2.220972e-06
# Length: 1530, dtype: float64

# %%
df_g = df.groupby([ '0_spleen', '1_spleen'])

# %%
df_g.head()

# %%
mdf.df_resid
# Out:
# 1528

# %%
mdf.resid
# Out:
# 0      -8.189541e-06
# 1      -7.509012e-06
# 2       9.912524e-07
# 3      -1.385631e-06
# 4       3.169971e-06
#             ...
# 1525   -8.168525e-06
# 1526   -8.275381e-06
# 1527   -3.669965e-06
# 1528    1.269974e-05
# 1529   -2.220972e-06
# Length: 1530, dtype: float64
