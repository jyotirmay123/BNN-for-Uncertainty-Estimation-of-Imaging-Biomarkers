# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import glob
import nibabel as nb
import itertools
import json
import sys
import statsmodels.api as sm
from statsmodels.formula.api import ols, wls
from statsmodels.formula.api import mixedlm
from patsy.contrasts import Treatment

from scipy import stats
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from statsmodels.iolib.table import (SimpleTable, default_txt_fmt)
from statsmodels.discrete.discrete_model import Probit, MNLogit
from statsmodels.tools import add_constant
from sklearn.feature_selection import SelectKBest, SelectPercentile, SelectFdr
from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn import metrics

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier


import seaborn as sns
sns.set(style="whitegrid")

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
np.random.seed(1024)

# %%
base_dir = '/home/abhijit/Jyotirmay/my_thesis'
basic_feats = ['age', 'sex', 'bmi_numeric']
spleen_sample_cols = ['0_spleen','1_spleen','2_spleen','3_spleen','4_spleen','5_spleen','6_spleen','7_spleen','8_spleen','9_spleen']
liver_sample_cols = ['0_liver','1_liver','2_liver','3_liver','4_liver','5_liver','6_liver','7_liver','8_liver','9_liver']
vols_feat = ['seg_liver', 'seg_spleen']
iou_feats = ['iou_spleen', 'iou_liver', 'iou_mean']
selected_model_feats = basic_feats + spleen_sample_cols + liver_sample_cols + vols_feat + iou_feats + ['volume_id', 'diabetes_status'] #+ ['iou_dot_seg_spleen_normalised', 'iou_dot_seg_liver_normalised']
selected_dataset_feats = basic_feats +  ['volume_id', 'diabetes_status'] + vols_feat
all_paths = [
#     {'full_bayesian': './projects/full_bayesian/reports/full_bayesian_KORA_v2/KORA/10_1571866968.4002764_concat_report_final.csv'},
    {'full_bayesian_0dot01': './projects/full_bayesian/reports/full_bayesian_KORA_v4/KORA/10_1572514598.527084_concat_report_final.csv'},
    {'MC_dropout_quicknat': './projects/MC_dropout_quicknat/reports/MC_dropout_quicknat_KORA_v2/KORA/10_1572006141.7793334_concat_report_final.csv'}, 
    {'probabilistic_quicknat': './projects/probabilistic_quicknat/reports/probabilistic_quicknat_KORA_v2/KORA/10_1571996796.7963011_concat_report_final.csv'}, 
    {'hierarchical_quicknat': './projects/hierarchical_quicknat/reports/hierarchical_quicknat_KORA_v2/KORA/10_1571905560.9377904_concat_report_final.csv'},
    {'dataset_KORA_processed': './dataset_groups/whole_body_datasets/KORA/all_processed_True_concat_report_final.csv'},
    {'UKB_MC_dropout_quicknat': './projects/MC_dropout_quicknat/reports/MC_dropout_quicknat_UKB_v2/UKB/0_0.0_concat_report_final.csv'},
    {'UKB_probabilistic_quicknat': './projects/probabilistic_quicknat/reports/probabilistic_quicknat_UKB_v2/UKB/10_1573834823.1121247_concat_report_final.csv'},
    {'UKB_hierarchical_quicknat': './projects/hierarchical_quicknat/reports/hierarchical_quicknat_UKB_v2/UKB/10_1574308007.2486243_concat_report_final.csv'},
    {'dataset_UKB_processed': './dataset_groups/whole_body_datasets/UKB/all_processed_True_concat_report_final.csv'}
]

ukb_paths = [
    {'MC_dropout_quicknat': './projects/MC_dropout_quicknat/reports/MC_dropout_quicknat_UKB_v2/UKB/0_0.0_concat_report_final.csv'},
    {'probabilistic_quicknat': './projects/probabilistic_quicknat/reports/probabilistic_quicknat_UKB_v2/UKB/10_1573834823.1121247_concat_report_final.csv'}
]

model_report_paths = {key:val for d in all_paths for key,val in d.items()}
# ukb_model_report_paths = {key:val for d in ukb_paths for key,val in d.items()}

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

def transform_to_categorical(df, categorical_features_list):
    for f in categorical_features_list:
        dfDummies = pd.get_dummies(df[f], prefix = f)
        df = pd.concat([df, dfDummies], axis=1)
    return df

def rename(df, cols_map=None):
    if cols_map is None:
        cols_map =  {'bmi-numeric':'bmi_numeric', 'blood-pressure-diastolic':'blood_pressure_diastolic', 'blood-pressure-systolic':'blood_pressure_systolic',
             'cholesterol-hdl':'cholesterol_hdl', 'cholesterol-ldl':'cholesterol_ldl', 'cholesterol-total':'cholesterol_total',
             'mri-liver-fat-artifacts':'mri_liver_fat_artifacts', 'mri-liver-fat-lobus-dexter':'mri_liver_fat_lobus_dexter', 
              'mri-liver-fat-lobus-sinister':'mri_liver_fat_lobus_sinister', 'mri-liver-fat-portal-vein':'mri_liver_fat_portal_vein',
             'meds-lipoprotein-lowering':'meds_lipoprotein_lowering', 'meds-antihypertensive':'meds_antihypertensive',
              'smoker_non-smoker':'smoker_non_smoker','alcohol-g/day':'alcohol_g_day'}
    df.rename(columns=cols_map, inplace=True)
    return df

def z_score_column_normalise(df, column_list):
    normalised_cols_map = {}
    for column in column_list:
        normalised_cols_map[column] = column+'_normalised'
#         df[normalised_cols_map[column]] = (df[column] - df[column].mean())/df[column].std(ddof=0)
        df[normalised_cols_map[column]] = (df[column] - df[column].min())/ (df[column].max() - df[column].min())
    return df, normalised_cols_map

def z_score_group_normalise(df, cols_to_normalise):
    normalised_cols_map = {}
    group_cols_value = df[cols_to_normalise].values
    mean, std = np.mean(group_cols_value), np.std(group_cols_value, ddof=0)
    for column in cols_to_normalise:
        normalised_cols_map[column] = 'normalised_'+column
        df[normalised_cols_map[column]] = (df[column] - mean)/std
    return df, normalised_cols_map

def pre_process_for_mlm(df, to_be_transpose_cols, value_name):
    cols = list(df.columns)
    cols_without_tobe_transposed_cols = list(set(cols) - set(to_be_transpose_cols))
    df = df.melt(id_vars=cols_without_tobe_transposed_cols, 
            value_vars=to_be_transpose_cols, 
            value_name=value_name)

    return df

def model_evaluation_matrics(file_paths_dict, cols_to_fetch):
    dicts = {}
    for model, path in file_paths_dict.items():
        if 'dataset' in model:
            continue
        df = pd.read_csv(path)
        dicts[model] = df[cols_to_fetch].iloc[1:].mean()
    return dicts

def individual_feature_stats(feats, df, target_col, categorical_feats=['diabetes_status', 'sex']):
    p_values = {}
    for f in feats:
        try:
            features_string = make_feature_string([f], categorical_feats)
            fii = ols(f'{target_col} ~ {features_string}', df).fit()
            feat_dict = fii.pvalues.to_dict()
            coeffs = fii.params
        
            for k, v in feat_dict.items():
                orig_key = k
                if k == 'Intercept':
                    k = f+'_Intercept'
                p_values[k] = v

                p_values[k+'_coeff'] = coeffs[orig_key]
            p_values['fitting_score'] = fii.rsquared
        except Exception as e:
            print(e)

    return p_values


def make_feature_string(feats, categorical_cols=[]):
    feat_str = '1+'
    for c_col in categorical_cols:
        if type(c_col) is tuple:
            if c_col[0] not in feats:
#                 print(f'{c_col} is not present in given feature list, SKIPPING IT!')
                continue
            feat_str += f'C({c_col[0]}, Treatment(reference={c_col[1]}))+'
            c_col = c_col[0]
        else:
            if c_col not in feats:
#                 print(f'{c_col} is not present in given feature list, SKIPPING IT!')
                continue
            feat_str += f'C({c_col}, Treatment)+'
        feats.remove(c_col)
    
    other_feats_str = '+'.join(feats)
    if other_feats_str is '':
        final_feat_str = feat_str[:-1]
    else:
        final_feat_str = feat_str + other_feats_str

    return final_feat_str
    



def normal_mixed_effect_model(df, target_col, features_string, group_col, L1_wt=None):
    if L1_wt is None:
        model = mixedlm(f'{target_col} ~ {features_string}', df, groups=df[group_col]).fit()
    else:
        model = mixedlm(f'{target_col} ~ {features_string}', df, groups=df[group_col]).fit_regularized(L1_wt=L1_wt)
    return model

def anova_test(ols_model):
    anova_stats = sm.stats.anova_lm(ols_model)
    return anova_stats

def df_from_nested_dicts(dicts):
    df = pd.concat({k+'_'+kk: pd.concat({kk:pd.DataFrame(vv, index=[0]).T}, axis=1) for k, v in dicts.items() for kk, vv in v.items()}, axis=1)
    return df

def df_from_nested_dicts_group(dicts):
    df = pd.concat({k+'_'+kk: pd.concat({kk:pd.DataFrame(vv, index=[0]).T}, axis=1) for k, v in dicts.items() for kk, vv in v.items()}, axis=1)
    return df

def highlight_significance(df, threshold=0.05):
    return df.style.applymap(lambda x: 'background-color : yellow' if x==True or x<threshold else '')


def discrete_group_feature_stats(feats, df, target_col, categorical_feats=['diabetes_status', 'sex'], is_classification=False):
    p_values = {}
    try:
#             features_string = f'1+C({f}, Treatment)' if f in categorical_feats else f'1+{f}'
        x = df[feats]
        y = df[target_col]
        x = add_constant(x)
        model = Probit(y, x)
        fii = model.fit()
        predicted = fii.predict(x)
#             print(model.pdf(x))
#         fii_ = fii.get_margeff()
#         print(fii.summary())
# #         print(fii_.summary())
        feat_dict = fii.pvalues.to_dict()
        coeffs = fii.params
        
        for k, v in feat_dict.items():
            p_values[k] = v
            p_values[k+'_coeff'] = coeffs[k]

        p_values['aic'] = fii.aic
        p_values['bic'] = fii.bic
        p_values['psuedo_r2'] = fii.prsquared
    except Exception as e:
        print('ERROR:', e)

    return p_values, fii, (y, predicted)

# def weighted_group_feats(df, target_col, features_string, alpha_col):
#     alpha = df[alpha_col].values
#     model = wls(f'{target_col} ~ {features_string}', df, weights=(1/(1-alpha))).fit()
#     return model

def discrete_weighted_group_feats(df, target_col, feats, alpha_col, class_freq=None):
    p_values = {}
    alpha = df[alpha_col].values
    x = df[feats]
    y = df[target_col]
    x = add_constant(x)
    fii = sm.GLM(y, x, family=sm.families.Binomial(sm.families.links.probit), missing='drop', var_weights=alpha).fit()
    predicted = fii.predict(x)
#     print(fii.summary())
#     print(fii.to_dict())
    
    feat_dict = fii.pvalues.to_dict()
    coeffs = fii.params

    for k, v in feat_dict.items():
        p_values[k] = v
        p_values[k+'_coeff'] = coeffs[k]

    p_values['aic'] = fii.aic
    p_values['bic'] = fii.bic
    sst_val = sum(map(lambda x: np.power(x,2),y-np.mean(y))) 
    sse_val = sum(map(lambda x: np.power(x,2),fii.resid_response)) 
    r2 = 1-(sse_val/sst_val)
    p_values['psuedo_r2'] = r2
    return p_values, fii, (y, predicted)

def normal_group_fit(df, target_col, features_string):
    p_values = {}
    fii = ols(f'{target_col} ~ {features_string}', df).fit()
    y = df[target_col].values
    predicted = fii.predict(df)
    feat_dict = fii.pvalues.to_dict()
    coeffs = fii.params

    for k, v in feat_dict.items():
        p_values[k] = v
        p_values[k+'_coeff'] = coeffs[k]

    p_values['aic'] = fii.aic
    p_values['bic'] = fii.bic
    p_values['psuedo_r2'] = fii.rsquared
    return p_values, fii, (y, predicted)

def weighted_group_feats(df, target_col, features_string, alpha_col):
    p_values = {}
    alpha = df[alpha_col].values
    fii = wls(f'{target_col} ~ {features_string}', df, weights=alpha).fit()
    y = df[target_col].values
    predicted = fii.predict(df)
    feat_dict = fii.pvalues.to_dict()
    coeffs = fii.params

    for k, v in feat_dict.items():
        p_values[k] = v
        p_values[k+'_coeff'] = coeffs[k]

    p_values['aic'] = fii.aic
    p_values['bic'] = fii.bic
    p_values['psuedo_r2'] = fii.rsquared
    return p_values, fii, (y, predicted)

# %%
def normalise_iou(df):
    for iou_col in ['iou_spleen', 'iou_liver']:
        iou = df[iou_col]
        iou = (iou - iou.min()) / (iou.max() - iou.min())
        df[f'{iou_col}_normalised'] = iou
    df['iou_mean_normalised'] = (df['iou_spleen_normalised'] + df['iou_liver_normalised']) / 2
    return df

# for model, path in model_report_paths.items():
#     if 'dataset' in model:
#         continue
#     print(model)
#     dfk = pd.read_csv(model_report_paths[model])
#     iou = dfk['iou_spleen']
    
#     print(iou.max(), iou.mean(), iou.min(), iou.std())

#     iou.plot.kde()
#     plt.show()
#     iou = (iou - iou.min()) / (iou.max() - iou.min())
#     print(iou.max(), iou.mean(), iou.min(), iou.std())
#     iou.plot.kde()
#     plt.show()
# #     s = np.random.normal(iou.mean(), 10*iou.std(), 1000)
# #     count, bins, ignored = plt.hist(s, 30, density=True)
# #     plt.show()

# %%
# sst_val = sum(map(lambda x: np.power(x,2),y-np.mean(y))) 
# sse_val = sum(map(lambda x: np.power(x,2),model.resid_response)) 
# r2 = 1-(sse_val/sst_val)

# %%
# r2

# %%
# print(logmodel.resid_deviance, logmodel.null_deviance, model.resid_response, logmodel.resid_response)

# %%
def plot_pdf(good_pdf, bad_pdf, ax):
    ax.fill(x, good_pdf, "g", alpha=0.5)
    ax.fill(x, bad_pdf,"r", alpha=0.5)
    ax.set_xlim([0,1])
    ax.set_ylim([0,5])
    ax.set_title("Probability Distribution", fontsize=14)
    ax.set_ylabel('Counts', fontsize=12)
    ax.set_xlabel('P(X="bad")', fontsize=12)
    ax.legend(["good","bad"])

def auc_roc(y_yp, title):
    y, predicted = y_yp
    y_p = np.where(predicted > 0.5, 1, 0)
    labels = [0, 1]
    y_1_mask = np.where(y==1, True, False)
    y_0_mask = np.where(y==0, True, False)
    xs = [predicted[y_0_mask], predicted[y_1_mask]]

    fig, ax0 = plt.subplots(nrows=1, ncols=1)
    colors = ['red','blue']
    ax0.hist(xs, 10, normed=1, histtype='bar', color=colors, label=labels)
    ax0.legend(prop={'size': 10})
    ax0.set_title('bars with legend')
    plt.show()
    
   
    fpr, tpr, thresholds = metrics.roc_curve(y, predicted, pos_label=1)
    auc_score = metrics.roc_auc_score(y, predicted)
 
#     f1_score = metrics.f1_score(y, y_p, labels=labels)
    print(f'{title}: auc_score: {auc_score}')
#     plt.scatter(predicted, y)
#     plt.show()
    plt.plot(fpr, tpr)
    plt.show()
#     print(list(y))
#     print(predicted)
    
#     print(y_p)
    
    cm = confusion_matrix(y, y_p, labels)
    print(cm)
#     fig = plt.figure()
#     ax = fig.add_subplot(111)
#     cax = ax.matshow(cm)
#     plt.title('Confusion matrix of the classifier')
#     fig.colorbar(cax)
#     ax.set_xticklabels([''] + labels)
#     ax.set_yticklabels([''] + labels)
#     plt.xlabel('Predicted')
#     plt.ylabel('True')
#     plt.show()
    
#     unique_elements, counts_elements = np.unique(predicted, return_counts=True)
#     plt.hist(predicted, bins=20)
#     plt.bar(unique_elements, counts_elements)
#     plt.show()
    
#     print(disp)
#     disp.ax_.set_title(title)

#     print(title)
#     print(disp.confusion_matrix)
#     print(f'{title}:::  fpr: {fpr}, tpr: {tpr}, threshold: {thresholds}')
    return auc_score, 1

def regression_plot(y_yp, title=''):
    y, predicted = y_yp
    print(title)
    plt.scatter(predicted, y)
    plt.show()
    
def random_forest_evaluations(df, target_col, feats):
    y = df[target_col]
    x = df[feats]
    kfold_rf = model_selection.KFold(n_splits=10, random_state=10)
    model_rf = RandomForestClassifier(n_estimators=100, max_features=3)
    results_rf = model_selection.cross_val_score(model_rf, x, y, cv=kfold_rf)
    print('Random Forest Out:', results_rf.mean())
    return results_rf.mean()

def bagging_evaluations(df, target_col, feats):
    y = df[target_col]
    x = df[feats]
    kfold = model_selection.KFold(n_splits=10, random_state=10)
    model_1 = BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100, random_state=10)
    results_1 = model_selection.cross_val_score(model_1, x, y, cv=kfold)
    print('Bagging Out:', results_1.mean())
    return results_1.mean()

def sgd_evaluator(df, target_col, feats):
    y = df[target_col]
    x = df[feats]
    kfold_sgb = model_selection.KFold(n_splits=10, random_state=10)
    model_sgb = GradientBoostingClassifier(n_estimators=100, random_state=10)
    results_sgb = model_selection.cross_val_score(model_sgb, x, y, cv=kfold_sgb)
    
    y_p = model_sgb.fit(x, y).predict(x)
    print('model score: ', model_sgb.score(x, y))
    auc_roc((y, y_p), 'sgd')
    print('Stochastic Gradient out:', results_sgb)
    return results_sgb.mean()

def voting_classifier_evaluator(df, target_col, feats, ensemble=None):
    y = df[target_col]
    x = df[feats]
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=10)

#     kfold_vc = model_selection.KFold(n_splits=10, random_state=10)
    if ensemble is None:
        # Lines 2 to 8
        estimators = []
    
        mod_rf = RandomForestClassifier(n_estimators=100, max_features=3)
        estimators.append(('rf', mod_rf))
        mod_bagging = BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100, random_state=10)
        estimators.append(('bagging', mod_bagging))
        mod_sgd = GradientBoostingClassifier(n_estimators=100, random_state=10)
        estimators.append(('sgd', mod_sgd))
        mod_lr = LogisticRegression()
        estimators.append(('logistic', mod_lr))
        mod_dt = DecisionTreeClassifier()
        estimators.append(('cart', mod_dt))
        mod_sv = SVC()
        estimators.append(('svm', mod_sv))

        # Lines 9 to 11
        
        ensemble = VotingClassifier(estimators)
#         print(estimators)
    #     results_vc = model_selection.cross_val_score(ensemble, x, y, cv=kfold_vc)
        ensemble.fit(X_train, y_train)
    else:
        X_train, X_test, y_train, y_test = x, x, y, y
    
    print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
#         print(ensemble)
    auc_roc((y_train, ensemble.predict(X_train)), 'ensemble')
    print('ensemble score train set: ',ensemble.score(X_train, y_train))
    auc_roc((y_test, ensemble.predict(X_test)), 'ensemble')
    print('ensemble score test set: ',ensemble.score(X_test, y_test))
#     print('Voting Classifier out:', results_vc.mean())
    return ensemble.score(X_test, y_test), ensemble

def aggregate_model_outputs(df, target_col, feats, dicts, model, key, ensemble=None):
#     dicts['rf'] = random_forest_evaluations(df, target_col, feats)
#     dicts[model][key]['bagging'] = bagging_evaluations(df, target_col, feats)
#     dicts[model][key]['sgd'] = sgd_evaluator(df, target_col, feats)
    dicts[model][key]['voting'], ensemble = voting_classifier_evaluator(df, target_col, feats, ensemble)
    
    return dicts, ensemble

# %%
cols_to_fetch = ['sncc', 'ged', 'iou_spleen', 'iou_liver', 'dice_spleen',
       'dice_liver', 'surface_distance_avg_spleen', 'surface_distance_avg_liver']
dicts = model_evaluation_matrics(model_report_paths, cols_to_fetch)
df_model_eval = pd.DataFrame.from_dict(dicts)
df_model_eval = df_model_eval.T
# df_model_eval.columns = cols_to_fetch
df_model_eval
# Out:
#                                 sncc       ged  iou_spleen  iou_liver  \
# full_bayesian_0dot01        0.440058  0.195726    0.778430   0.843838
# MC_dropout_quicknat         0.400336  0.166126    0.821658   0.878743
# probabilistic_quicknat      0.164762  0.228213    0.988126   0.992441
# hierarchical_quicknat       0.188499  0.209206    0.983803   0.989027
# UKB_MC_dropout_quicknat          NaN       NaN    0.730973   0.807269
# UKB_probabilistic_quicknat       NaN       NaN    0.965202   0.980590
# UKB_hierarchical_quicknat        NaN       NaN    0.935690   0.939154
#
#                             dice_spleen  dice_liver  \
# full_bayesian_0dot01           0.876213    0.921414
# MC_dropout_quicknat            0.897251    0.937764
# probabilistic_quicknat         0.873734    0.925382
# hierarchical_quicknat          0.883031    0.932817
# UKB_MC_dropout_quicknat             NaN         NaN
# UKB_probabilistic_quicknat          NaN         NaN
# UKB_hierarchical_quicknat           NaN         NaN
#
#                             surface_distance_avg_spleen  \
# full_bayesian_0dot01                           0.878335
# MC_dropout_quicknat                            0.915783
# probabilistic_quicknat                         0.875181
# hierarchical_quicknat                          0.897130
# UKB_MC_dropout_quicknat                             NaN
# UKB_probabilistic_quicknat                          NaN
# UKB_hierarchical_quicknat                           NaN
#
#                             surface_distance_avg_liver
# full_bayesian_0dot01                          0.817338
# MC_dropout_quicknat                           0.871014
# probabilistic_quicknat                        0.827286
# hierarchical_quicknat                         0.854920
# UKB_MC_dropout_quicknat                            NaN
# UKB_probabilistic_quicknat                         NaN
# UKB_hierarchical_quicknat                          NaN

# %% [markdown]
# # Post Process reports

# %%
dfs = {}
common_vols = None

for model, path in model_report_paths.items():
    if 'dataset' in model:
        continue
    if 'UKB' in model:
        continue
    print(model)
    df = pd.read_csv(path)
    df = rename(df)
    dfs[model] = df
    vols = df[(df['iou_mean']>0.51) & (df['iou_spleen'] != 1.0) & (df['iou_liver'] != 1.0)].volume_id.values
    if common_vols is None:
        common_vols = vols
    else:
        common_vols = np.intersect1d(common_vols, vols)
    print(common_vols.shape)

df_dataset = pd.read_csv(model_report_paths['dataset_KORA_processed'])
df_dataset = rename(df_dataset)
dfs['dataset_KORA_processed']  = df_dataset

for model, df in dfs.items():
    if 'dataset' in model:
        selected_feats = selected_dataset_feats
    else:
        selected_feats = selected_model_feats #+ ['iou_spleen_normalised', 'iou_liver_normalised', 'iou_mean_normalised']
     
        
    dfs[model] = df[df.volume_id.isin(common_vols)][selected_feats]
    df, normalised_cols = z_score_column_normalise(dfs[model], ['seg_spleen', 'seg_liver'])
    if 'dataset' not in model:
        df['iou_dot_seg_spleen'] = df['iou_spleen'] * df['seg_spleen_normalised']
        df['iou_dot_seg_liver'] = df['iou_liver'] * df['seg_liver_normalised']
        df, _ =  z_score_column_normalise(df, ['iou_dot_seg_spleen', 'iou_dot_seg_liver'])
        df = normalise_iou(df)
    dfs[model] = df
    print('model shape:', dfs[model].shape)

## Change pre-diabetic state to diabetic
for model, df in dfs.items():
    df.loc[df['diabetes_status']==2, 'diabetes_status'] = 1
    dfs[model] = df
    dfs[model].to_csv(f'final_feats_{model}.csv', index=False)
# Out:
# full_bayesian_0dot01
# (148,)
# MC_dropout_quicknat
# (147,)
# probabilistic_quicknat
# (147,)
# hierarchical_quicknat
# (147,)
# model shape: (147, 39)
# model shape: (147, 39)
# model shape: (147, 39)
# model shape: (147, 39)
# model shape: (147, 9)

# %%
dfs_ukb = {}
common_vols = None

for model, path in model_report_paths.items():
    if 'dataset' in model:
        continue
    if 'UKB' not in model:
        continue
    print(model)
    df = pd.read_csv(path)
    df = rename(df)
    dfs_ukb[model] = df
    vols = df[(df['iou_mean']>0.51) & (df['iou_spleen'] != 1.0) & (df['iou_liver'] != 1.0)].volume_id.values
    if common_vols is None:
        common_vols = vols
    else:
        common_vols = np.intersect1d(common_vols, vols)
    print(common_vols.shape)

df_dataset = pd.read_csv(model_report_paths['dataset_UKB_processed'])
# common_vols = np.intersect1d(common_vols, df_dataset.volume_id.values)
df_dataset = rename(df_dataset)
dfs_ukb['dataset_UKB_processed']  = df_dataset

for model, df in dfs_ukb.items():
    if 'dataset' in model:
        selected_feats = selected_dataset_feats
    else:
        selected_feats = selected_model_feats #+ ['iou_spleen_normalised', 'iou_liver_normalised', 'iou_mean_normalised']
        
    dfs_ukb[model] = df[df.volume_id.isin(common_vols)][selected_feats]
    df, normalised_cols = z_score_column_normalise(dfs_ukb[model], ['seg_spleen', 'seg_liver'])
    if 'dataset' not in model:
        df['iou_dot_seg_spleen'] = df['iou_spleen'] * df['seg_spleen_normalised']
        df['iou_dot_seg_liver'] = df['iou_liver'] * df['seg_liver_normalised']
        df, _ =  z_score_column_normalise(df, ['iou_dot_seg_spleen', 'iou_dot_seg_liver'])
        df = normalise_iou(df)
    dfs_ukb[model] = df
    print('model shape:', dfs_ukb[model].shape)
    
# df_dataset = pd.read_csv(model_report_paths['dataset_KORA_processed'])
# df_dataset = rename(df_dataset)
# dfs['dataset_KORA_processed'] = df[df.volume_id.isin(common_vols)][selected_dataset_feats]
# print(dfs['dataset_KORA_processed'].shape)

## Change pre-diabetic state to diabetic
for model, df in dfs_ukb.items():
    df.loc[df['diabetes_status']==2, 'diabetes_status'] = 1
    dfs_ukb[model] = df
    dfs_ukb[model].to_csv(f'final_feats_{model}.csv', index=False)
# Out:
# UKB_MC_dropout_quicknat
# (18201,)
# UKB_probabilistic_quicknat
# (17328,)
# UKB_hierarchical_quicknat
# (16574,)
# model shape: (16574, 39)
# model shape: (16574, 39)
# model shape: (16574, 39)
# model shape: (6, 9)

# %% [markdown]
# # Equations
#
# Eq-1: Diabetes_status = a0 +a1*age + a2*sex + a3*BMI
#
# Eq-2: Diabetes_status = a0 +a1*age + a2*sex + a3*BMI + a4*seg_<spleen|liver>
#
# Eq-3: Diabetes_status = a0 +a1*age + a2*sex + a3*BMI + a4*seg_<spleen|liver> + a5*iou_<spleen|liver>
#
# Eq-4: (Diabetes_status == a0 +a1*age + a2*sex + a3*BMI + a4*seg_<spleen|liver>) * iou_<spleen|liver>
#
# Eq-5: Diabetes_status = a0 +a1*age + a2*sex + a3*BMI +  a4*seg_<spleen|liver>)i

# %% [markdown]
# # Group features (eq 1, eq 2, eq 3 and eq 4)

# %%
feats = basic_feats
dicts = {}
anova_test_dicts = {}
global_kora_models = {}
for model, df in dfs.items():
#     
#     df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver'])
#     df = df.fillna(0)

    dicts[model] = {}
    global_kora_models[model] = {}
    target_col = 'diabetes_status'

#     Equation 1 process
    p_values, statsmodel, y_yp = discrete_group_feature_stats(basic_feats, df, target_col, ['sex'], True)
#     print(y_yp)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_csv_features')
    dicts[model][target_col] = p_values
    dicts[model][target_col]['auc'] = auc_score
    dicts[model][target_col]['f1'] = f1_score
    dicts, global_kora_models[model]['normal'] = aggregate_model_outputs(df, target_col, basic_feats, dicts, model, target_col)
        
#     Equation 2 process
    feats = basic_feats + [ 'seg_spleen_normalised', 'seg_liver_normalised']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_with_seg_volumes')
    dicts[model][target_col+'_with_seg_volumes'] = p_values
    dicts[model][target_col+'_with_seg_volumes']['auc'] = auc_score
    dicts[model][target_col+'_with_seg_volumes']['f1'] = f1_score
    dicts, global_kora_models[model]['seg'] = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+'_with_seg_volumes')
    if 'dataset' in model:
        continue
    
#     Equation 3 process
    feats = basic_feats + [ 'seg_spleen_normalised', 'seg_liver_normalised', 'iou_spleen', 'iou_liver']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_with_seg_iou')
    dicts[model][target_col+'_with_seg_and_iou'] = p_values
    dicts[model][target_col+'_with_seg_and_iou']['auc'] = auc_score
    dicts[model][target_col+'_with_seg_and_iou']['f1'] = f1_score
    dicts, global_kora_models[model]['seg_iou'] = aggregate_model_outputs(df, target_col, feats, dicts, model,target_col+'_with_seg_and_iou')
    
#     Equation 3.1 process
    feats = basic_feats + [ 'seg_spleen_normalised', 'seg_liver_normalised', 'iou_dot_seg_spleen_normalised', 'iou_dot_seg_liver_normalised']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_with_seg_dot_iou')
    dicts[model][target_col+'_with_seg_dot_iou'] = p_values
    dicts[model][target_col+'_with_seg_dot_iou']['auc'] = auc_score
    dicts[model][target_col+'_with_seg_dot_iou']['f1'] = f1_score
    dicts, global_kora_models[model]['seg_dot_iou'] = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+'_with_seg_dot_iou')
    
    
    
#     Equation 4 process
    feats = basic_feats + [ 'seg_spleen_normalised', 'seg_liver_normalised']
    p_values, statsmodel, y_yp = discrete_weighted_group_feats(df, target_col, feats, 'iou_mean_normalised')
    auc_score, f1_score = auc_roc(y_yp, f'{model}_with_seg_reg_iou')
    dicts[model][target_col+'_with_regularised_seg_volumes'] = p_values
    dicts[model][target_col+'_with_regularised_seg_volumes']['auc'] = auc_score
    dicts[model][target_col+'_with_regularised_seg_volumes']['f1'] = f1_score
    dicts, global_kora_models[model]['seg_reg_iou'] = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+'_with_regularised_seg_volumes')
    

    
p_value_df = df_from_nested_dicts(dicts).T
p_value_df_styler = highlight_significance(p_value_df, 0.05)
p_value_df_styler
# Out:
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# full_bayesian_0dot01_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (98, 3) (98,) (49, 3) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6196581196581198
# [[28  8]
#  [ 7  6]]
# ensemble score test set:  0.6938775510204082
# Optimization terminated successfully.
#          Current function value: 0.453328
#          Iterations 6
# full_bayesian_0dot01_with_seg_volumes: auc_score: 0.8515463917525773
# [[87 10]
#  [18 32]]
# (98, 5) (98,) (49, 5) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.5811965811965811
# [[28  8]
#  [ 8  5]]
# ensemble score test set:  0.673469387755102
# Optimization terminated successfully.
#          Current function value: 0.423270
#          Iterations 6
# full_bayesian_0dot01_with_seg_iou: auc_score: 0.8682474226804124
# [[88  9]
#  [20 30]]
# (98, 7) (98,) (49, 7) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6474358974358975
# [[30  6]
#  [ 7  6]]
# ensemble score test set:  0.7346938775510204
# Optimization terminated successfully.
#          Current function value: 0.410027
#          Iterations 7
# full_bayesian_0dot01_with_seg_dot_iou: auc_score: 0.8744329896907217
# [[86 11]
#  [16 34]]
# (98, 7) (98,) (49, 7) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6335470085470085
# [[29  7]
#  [ 7  6]]
# ensemble score test set:  0.7142857142857143
# full_bayesian_0dot01_with_seg_reg_iou: auc_score: 0.8513402061855669
# [[87 10]
#  [17 33]]
# (98, 5) (98,) (49, 5) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6196581196581198
# [[28  8]
#  [ 7  6]]
# ensemble score test set:  0.6938775510204082
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# MC_dropout_quicknat_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (98, 3) (98,) (49, 3) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6196581196581198
# [[28  8]
#  [ 7  6]]
# ensemble score test set:  0.6938775510204082
# Optimization terminated successfully.
#          Current function value: 0.438315
#          Iterations 6
# MC_dropout_quicknat_with_seg_volumes: auc_score: 0.86
# [[86 11]
#  [18 32]]
# (98, 5) (98,) (49, 5) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6196581196581198
# [[28  8]
#  [ 7  6]]
# ensemble score test set:  0.6938775510204082
# Optimization terminated successfully.
#          Current function value: 0.416056
#          Iterations 7
# MC_dropout_quicknat_with_seg_iou: auc_score: 0.8665979381443298
# [[89  8]
#  [16 34]]
# (98, 7) (98,) (49, 7) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6858974358974358
# [[30  6]
#  [ 6  7]]
# ensemble score test set:  0.7551020408163265
# Optimization terminated successfully.
#          Current function value: 0.402951
#          Iterations 7
# MC_dropout_quicknat_with_seg_dot_iou: auc_score: 0.8738144329896907
# [[88  9]
#  [17 33]]
# (98, 7) (98,) (49, 7) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6196581196581198
# [[28  8]
#  [ 7  6]]
# ensemble score test set:  0.6938775510204082
# MC_dropout_quicknat_with_seg_reg_iou: auc_score: 0.8608247422680412
# [[87 10]
#  [18 32]]
# (98, 5) (98,) (49, 5) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6335470085470085
# [[29  7]
#  [ 7  6]]
# ensemble score test set:  0.7142857142857143
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# probabilistic_quicknat_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (98, 3) (98,) (49, 3) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6196581196581198
# [[28  8]
#  [ 7  6]]
# ensemble score test set:  0.6938775510204082
# Optimization terminated successfully.
#          Current function value: 0.446703
#          Iterations 6
# probabilistic_quicknat_with_seg_volumes: auc_score: 0.8560824742268041
# [[87 10]
#  [19 31]]
# (98, 5) (98,) (49, 5) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6335470085470085
# [[29  7]
#  [ 7  6]]
# ensemble score test set:  0.7142857142857143
# Optimization terminated successfully.
#          Current function value: 0.418020
#          Iterations 7
# probabilistic_quicknat_with_seg_iou: auc_score: 0.8649484536082473
# [[87 10]
#  [18 32]]
# (98, 7) (98,) (49, 7) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6997863247863247
# [[31  5]
#  [ 6  7]]
# ensemble score test set:  0.7755102040816326
# Optimization terminated successfully.
#          Current function value: 0.393903
#          Iterations 8
# probabilistic_quicknat_with_seg_dot_iou: auc_score: 0.8818556701030928
# [[88  9]
#  [15 35]]
# (98, 7) (98,) (49, 7) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.5950854700854701
# [[29  7]
#  [ 8  5]]
# ensemble score test set:  0.6938775510204082
# probabilistic_quicknat_with_seg_reg_iou: auc_score: 0.856701030927835
# [[87 10]
#  [17 33]]
# (98, 5) (98,) (49, 5) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.608974358974359
# [[30  6]
#  [ 8  5]]
# ensemble score test set:  0.7142857142857143
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# hierarchical_quicknat_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (98, 3) (98,) (49, 3) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6196581196581198
# [[28  8]
#  [ 7  6]]
# ensemble score test set:  0.6938775510204082
# Optimization terminated successfully.
#          Current function value: 0.447388
#          Iterations 6
# hierarchical_quicknat_with_seg_volumes: auc_score: 0.8579381443298969
# [[87 10]
#  [18 32]]
# (98, 5) (98,) (49, 5) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6335470085470085
# [[29  7]
#  [ 7  6]]
# ensemble score test set:  0.7142857142857143
# Optimization terminated successfully.
#          Current function value: 0.426626
#          Iterations 7
# hierarchical_quicknat_with_seg_iou: auc_score: 0.8628865979381443
# [[88  9]
#  [19 31]]
# (98, 7) (98,) (49, 7) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6965811965811965
# [[28  8]
#  [ 5  8]]
# ensemble score test set:  0.7346938775510204
# Optimization terminated successfully.
#          Current function value: 0.420213
#          Iterations 7
# hierarchical_quicknat_with_seg_dot_iou: auc_score: 0.8703092783505154
# [[86 11]
#  [16 34]]
# (98, 7) (98,) (49, 7) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6720085470085471
# [[29  7]
#  [ 6  7]]
# ensemble score test set:  0.7346938775510204
# hierarchical_quicknat_with_seg_reg_iou: auc_score: 0.8569072164948454
# [[87 10]
#  [17 33]]
# (98, 5) (98,) (49, 5) (49,)
# ensemble: auc_score: 1.0
# [[61  0]
#  [ 0 37]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6335470085470085
# [[29  7]
#  [ 7  6]]
# ensemble score test set:  0.7142857142857143
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# dataset_KORA_processed_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (98, 3) (98,) (49, 3) (49,)
# ensemble: auc_score: 1.0
# [[70  0]
#  [ 0 28]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6986531986531986
# [[23  4]
#  [10 12]]
# ensemble score test set:  0.7142857142857143
# Optimization terminated successfully.
#          Current function value: 0.434546
#          Iterations 6
# dataset_KORA_processed_with_seg_volumes: auc_score: 0.8604123711340206
# [[86 11]
#  [19 31]]
# (98, 5) (98,) (49, 5) (49,)
# ensemble: auc_score: 1.0
# [[70  0]
#  [ 0 28]]
# ensemble score train set:  1.0
# ensemble: auc_score: 0.6531986531986532
# [[23  4]
#  [12 10]]
# ensemble score test set:  0.673469387755102
# <style  type="text/css" >
#     #T_230cb200_16b7_11ea_af61_cd32309eb88erow0_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow0_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow0_col7 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow0_col8 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow0_col9 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow0_col23 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow1_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow1_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow1_col7 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow1_col8 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow1_col9 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow1_col22 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow2_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow2_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow2_col7 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow2_col8 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow2_col9 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow2_col15 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow2_col16 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow2_col19 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow2_col22 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col7 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col8 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col9 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col10 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col11 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col12 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col19 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col21 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow3_col22 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow4_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow4_col4 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow4_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow4_col7 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow4_col8 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow4_col9 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow4_col22 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow5_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow5_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow5_col7 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow5_col8 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow5_col9 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow5_col23 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow6_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow6_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow6_col7 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow6_col8 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow6_col9 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow6_col19 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow6_col22 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow7_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow7_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow7_col8 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow7_col9 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow7_col15 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow7_col16 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow7_col19 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow7_col21 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow7_col22 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col7 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col8 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col9 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col10 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col11 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col12 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col19 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col21 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow8_col22 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow9_col0 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow9_col4 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow9_col5 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88erow9_col7 {
#             background-color :  yellow;
#         }    #T_230cb200_16b7_11ea_af61_cd32309eb88e

# %%
# !pip install shap
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/c1/24/5fe7237b2eca13ee0cfb100bec8c23f4e69ce9df852a64b0493d49dae4e0/xgboost-0.90-py2.py3-none-manylinux1_x86_64.whl (142.8MB)
#      |████████████████████████████████| 142.8MB 2.4MB/s eta 0:00:01     |█████████████████████████▋      | 114.1MB 4.3MB/s eta 0:00:07
# Requirement already satisfied: numpy in /home/jyotirmay/anaconda3/lib/python3.7/site-packages (from xgboost) (1.17.2)
# Requirement already satisfied: scipy in /home/jyotirmay/anaconda3/lib/python3.7/site-packages (from xgboost) (1.3.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-0.90

# %% [markdown]
# # Ensemble Techniques

# %%
import shap 
import xgboost

shap.initjs()
for model, df in dfs.items():
    feats = basic_feats + [ 'seg_spleen_normalised', 'seg_liver_normalised',  'iou_spleen', 'iou_liver']
    x = df[feats]
    y = df['diabetes_status']
    
    model = RandomForestClassifier(n_estimators=100, max_features=3).fit(x, y)
#     model = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(x, label=y), 100)
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(x)
    break
print(np.array(shap_values).shape)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# (2, 147, 7)

# %%
shap.force_plot(explainer.expected_value, shap_values, x)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-87-05fbe6188b65> in <module>
# ----> 1 shap.force_plot(explainer.expected_value, shap_values, x)
#
# ~/anaconda3/lib/python3.7/site-packages/shap/plots/force.py in force_plot(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation)
#      76
#      77
# ---> 78     assert not type(shap_values) == list, "The shap_values arg looks looks multi output, try shap_values[i]."
#      79
#      80     link = convert_to_link(link)
#
# AssertionError: The shap_values arg looks looks multi output, try shap_values[i].

# %%
shap.force_plot(explainer.expected_value[0], shap_values[0], x)
# Out:
# <div id='iYN1PZ3T31P53Y1VTRPN3'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["output value"], "baseValue": 0.6576870748299322, "link": "identity", "featureNames": ["age", "sex", "bmi_numeric", "seg_spleen_normalised", "seg_liver_normalised", "iou_spleen", "iou_liver"], "explanations": [{"outValue": 0.99, "simIndex": 81.0, "features": {"0": {"effect": 0.12407640870752353, "value": 48.0}, "1": {"effect": 0.025491554030242607, "value": 0.0}, "2": {"effect": 0.12367254591501897, "value": 24.12}, "3": {"effect": 0.027029094109442157, "value": 0.2434526728788622}, "4": {"effect": 0.04061885945181661, "value": 0.1637384343486849}, "5": {"effect": 0.01622753198719648, "value": 0.7649495210975925}, "6": {"effect": -0.024803069031172395, "value": 0.8090090233842079}}}, {"outValue": 0.8400000000000003, "simIndex": 129.0, "features": {"0": {"effect": 0.1494477947631525, "value": 50.0}, "1": {"effect": -0.0018514446263328877, "value": 1.0}, "2": {"effect": -0.034867861968126045, "value": 29.35}, "3": {"effect": -0.01158232141153313, "value": 0.405223148602256}, "4": {"effect": 0.011616040558982141, "value": 0.4620715944138337}, "5": {"effect": 0.019024768345510784, "value": 0.8384698567180319}, "6": {"effect": 0.05052594950841477, "value": 0.8785148594593143}}}, {"outValue": 0.9100000000000001, "simIndex": 53.0, "features": {"0": {"effect": 0.02343909794696967, "value": 57.0}, "1": {"effect": -0.021736679759048184, "value": 1.0}, "2": {"effect": 0.13046990981797846, "value": 25.85}, "3": {"effect": 0.05392707317671471, "value": 0.08881804806277586}, "4": {"effect": 0.04514165730047947, "value": 0.13788682122188722}, "5": {"effect": 0.018080926877090075, "value": 0.7707633221315411}, "6": {"effect": 0.0029909398098838364, "value": 0.8424829954654575}}}, {"outValue": 1.0, "simIndex": 99.0, "features": {"0": {"effect": 0.10512031214202017, "value": 47.0}, "1": {"effect": 0.021004285998206855, "value": 0.0}, "2": {"effect": 0.13294763659448175, "value": 20.68}, "3": {"effect": 0.013611742720569135, "value": 0.3151299656694458}, "4": {"effect": 0.0398911911060376, "value": 0.1538423457541869}, "5": {"effect": 0.025415478797652737, "value": 0.7555138432660723}, "6": {"effect": 0.004322277811099726, "value": 0.8360395586057964}}}, {"outValue": 0.07999999999999996, "simIndex": 45.0, "features": {"0": {"effect": -0.10707848856566973, "value": 58.0}, "1": {"effect": -0.03646545305605273, "value": 1.0}, "2": {"effect": -0.2887458059066885, "value": 36.73}, "3": {"effect": -0.02634292717805844, "value": 0.3486758214811182}, "4": {"effect": -0.03981877859465964, "value": 0.3441007133698682}, "5": {"effect": -0.048946848746680274, "value": 0.8845148473442075}, "6": {"effect": -0.0302887727821228, "value": 0.8737586025985248}}}, {"outValue": 0.8100000000000003, "simIndex": 120.0, "features": {"0": {"effect": -0.007212090706953735, "value": 60.0}, "1": {"effect": 0.061498298345663165, "value": 0.0}, "2": {"effect": -0.10957657445590431, "value": 30.83}, "3": {"effect": 0.01809792857956951, "value": 0.34693477194703287}, "4": {"effect": 0.022294361152783975, "value": 0.3241105153985911}, "5": {"effect": -0.008435287230790097, "value": 0.8724807812175358}, "6": {"effect": 0.1756462894856996, "value": 0.9107688083111584}}}, {"outValue": 0.9800000000000002, "simIndex": 135.0, "features": {"0": {"effect": 0.1408564134076346, "value": 52.0}, "1": {"effect": -0.010099356750766382, "value": 1.0}, "2": {"effect": 0.028815332965858642, "value": 28.73}, "3": {"effect": 0.02563058794185013, "value": 0.2805787150564002}, "4": {"effect": 0.04155970022374971, "value": 0.379694948984896}, "5": {"effect": 0.03146017065080726, "value": 0.7757373400111297}, "6": {"effect": 0.06409007673093396, "value": 0.8860108879070294}}}, {"outValue": 1.0000000000000002, "simIndex": 103.0, "features": {"0": {"effect": 0.09404586464415184, "value": 51.0}, "1": {"effect": 0.01667454846220745, "value": 0.0}, "2": {"effect": 0.13151924989502184, "value": 22.99}, "3": {"effect": 0.0394512288 ...

# %%
shap.dependence_plot("sex", shap_values[0], x)

# %%
shap.dependence_plot("bmi_numeric", shap_values[0], x)

# %%
shap.dependence_plot("age", shap_values[0], x)

# %%
shap.dependence_plot("seg_liver_normalised", shap_values[0], x)

# %%
feats = basic_feats
dicts = {}
anova_test_dicts = {}
for model, df in dfs_ukb.items():
#     
#     df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver'])
#     df = df.fillna(0)
    print(model)
    if 'UKB' not in model:
#         print('dataset cannot be processed!')
        continue
    if 'dataset' in model:
        continue
        
    dicts[model] = {}
    k_mod = model[4:]
    print(k_mod)
    target_col = 'diabetes_status'

#     Equation 1 process
    p_values, statsmodel, y_yp = discrete_group_feature_stats(basic_feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_csv_feats')
    dicts[model][target_col] = p_values
    dicts[model][target_col]['auc'] = auc_score
    dicts[model][target_col]['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, basic_feats, dicts, model, target_col, global_kora_models[k_mod]['normal'])
    
#     Equation 2 process
    feats = basic_feats + [ 'seg_spleen_normalised', 'seg_liver_normalised']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_seg')
    dicts[model][target_col+'_with_seg_volumes'] = p_values
    dicts[model][target_col+'_with_seg_volumes']['auc'] = auc_score
    dicts[model][target_col+'_with_seg_volumes']['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+'_with_seg_volumes', global_kora_models[k_mod]['seg'])
    
#     Equation 3 process
    feats = basic_feats + [ 'seg_spleen_normalised', 'seg_liver_normalised', 'iou_spleen', 'iou_liver']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_seg_iou')
    dicts[model][target_col+'_with_seg_and_iou'] = p_values
    dicts[model][target_col+'_with_seg_and_iou']['auc'] = auc_score
    dicts[model][target_col+'_with_seg_and_iou']['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+'_with_seg_and_iou', global_kora_models[k_mod]['seg_iou'])
    
    #     Equation 4.0 process
    feats = basic_feats + [ 'seg_spleen_normalised', 'seg_liver_normalised']
    p_values, statsmodel, y_yp = discrete_weighted_group_feats(df, target_col, feats, 'iou_mean', class_freq=[15000, 1000])
    auc_score, f1_score = auc_roc(y_yp, f'{model}_csv_feats')
    dicts[model][target_col+'_seg_reg_iou'] = p_values
    dicts[model][target_col+'_seg_reg_iou']['auc'] = auc_score
    dicts[model][target_col+'_seg_reg_iou']['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+'_seg_reg_iou', global_kora_models[k_mod]['seg_reg_iou'])
# #     Equation 4.1 process
#     feats = basic_feats + [ 'seg_spleen_normalised']
#     p_values, statsmodel = discrete_weighted_group_feats(df, target_col, feats, 'iou_spleen')
#     dicts[model][target_col+'_reg_iou_spleen'] = p_values
    
#     #     Equation 4.2 process
#     feats = basic_feats + [ 'seg_liver_normalised']
#     p_values, statsmodel = discrete_weighted_group_feats(df, target_col, feats, 'iou_liver')
#     dicts[model][target_col+'_reg_iou_liver'] = p_values

p_value_df = df_from_nested_dicts(dicts).T
p_value_df_styler = highlight_significance(p_value_df, 0.05)
p_value_df_styler
# Out:
# UKB_MC_dropout_quicknat
# MC_dropout_quicknat
# Optimization terminated successfully.
#          Current function value: 0.182250
#          Iterations 7
# UKB_MC_dropout_quicknat_csv_feats: auc_score: 0.7389245764404656
# [[15733     1]
#  [  839     1]]
# (16574, 3) (16574,) (16574, 3) (16574,)
# ensemble: auc_score: 0.6098663343562923
# [[10856  4878]
#  [  395   445]]
# ensemble score train set:  0.6818510920719199
# ensemble: auc_score: 0.6098663343562923
# [[10856  4878]
#  [  395   445]]
# ensemble score test set:  0.6818510920719199
# Optimization terminated successfully.
#          Current function value: 0.181826
#          Iterations 7
# UKB_MC_dropout_quicknat_seg: auc_score: 0.7415443201559256
# [[15733     1]
#  [  839     1]]
# (16574, 5) (16574,) (16574, 5) (16574,)
# ensemble: auc_score: 0.6237392332044042
# [[9869 5865]
#  [ 319  521]]
# ensemble score train set:  0.6268854832870762
# ensemble: auc_score: 0.6237392332044042
# [[9869 5865]
#  [ 319  521]]
# ensemble score test set:  0.6268854832870762
# Optimization terminated successfully.
#          Current function value: 0.181794
#          Iterations 7
# UKB_MC_dropout_quicknat_seg_iou: auc_score: 0.7415527187104662
# [[15733     1]
#  [  839     1]]
# (16574, 7) (16574,) (16574, 7) (16574,)
# ensemble: auc_score: 0.6451150677634725
# [[10448  5286]
#  [  314   526]]
# ensemble score train set:  0.6621213949559551
# ensemble: auc_score: 0.6451150677634725
# [[10448  5286]
#  [  314   526]]
# ensemble score test set:  0.6621213949559551
# UKB_MC_dropout_quicknat_csv_feats: auc_score: 0.741497484973397
# [[15733     1]
#  [  839     1]]
# (16574, 5) (16574,) (16574, 5) (16574,)
# ensemble: auc_score: 0.6312060021669783
# [[9823 5911]
#  [ 304  536]]
# ensemble score train set:  0.6250150838662966
# ensemble: auc_score: 0.6312060021669783
# [[9823 5911]
#  [ 304  536]]
# ensemble score test set:  0.6250150838662966
# UKB_probabilistic_quicknat
# probabilistic_quicknat
# Optimization terminated successfully.
#          Current function value: 0.182250
#          Iterations 7
# UKB_probabilistic_quicknat_csv_feats: auc_score: 0.7389245764404656
# [[15733     1]
#  [  839     1]]
# (16574, 3) (16574,) (16574, 3) (16574,)
# ensemble: auc_score: 0.6084093743001204
# [[10960  4774]
#  [  403   437]]
# ensemble score train set:  0.6876432967298178
# ensemble: auc_score: 0.6084093743001204
# [[10960  4774]
#  [  403   437]]
# ensemble score test set:  0.6876432967298178
# Optimization terminated successfully.
#          Current function value: 0.182229
#          Iterations 7
# UKB_probabilistic_quicknat_seg: auc_score: 0.739056305120243
# [[15733     1]
#  [  839     1]]
# (16574, 5) (16574,) (16574, 5) (16574,)
# ensemble: auc_score: 0.6082261193532961
# [[10692  5042]
#  [  389   451]]
# ensemble score train set:  0.6723180885724629
# ensemble: auc_score: 0.6082261193532961
# [[10692  5042]
#  [  389   451]]
# ensemble score test set:  0.6723180885724629
# Optimization terminated successfully.
#          Current function value: 0.182201
#          Iterations 7
# UKB_probabilistic_quicknat_seg_iou: auc_score: 0.7392913133220748
# [[15733     1]
#  [  839     1]]
# (16574, 7) (16574,) (16574, 7) (16574,)
# ensemble: auc_score: 0.6354412191977337
# [[9488 6246]
#  [ 279  561]]
# ensemble score train set:  0.6063110896585012
# ensemble: auc_score: 0.6354412191977337
# [[9488 6246]
#  [ 279  561]]
# ensemble score test set:  0.6063110896585012
# UKB_probabilistic_quicknat_csv_feats: auc_score: 0.7390653846386654
# [[15733     1]
#  [  839     1]]
# (16574, 5) (16574,) (16574, 5) (16574,)
# ensemble: auc_score: 0.6075319901699081
# [[10333  5401]
#  [  371   469]]
# ensemble score train set:  0.6517436949438881
# ensemble: auc_score: 0.6075319901699081
# [[10333  5401]
#  [  371   469]]
# ensemble score test set:  0.6517436949438881
# UKB_hierarchical_quicknat
# hierarchical_quicknat
# Optimization terminated successfully.
#          Current function value: 0.182250
#          Iterations 7
# UKB_hierarchical_quicknat_csv_feats: auc_score: 0.7389245764404656
# [[15733     1]
#  [  839     1]]
# (16574, 3) (16574,) (16574, 3) (16574,)
# ensemble: auc_score: 0.6213897564873159
# [[10844  4890]
#  [  375   465]]
# ensemble score train set:  0.6823337757934114
# ensemble: auc_score: 0.6213897564873159
# [[10844  4890]
#  [  375   465]]
# ensemble score test set:  0.6823337757934114
# Optimization terminated successfully.
#          Current function value: 0.182219
#          Iterations 7
# UKB_hierarchical_quicknat_seg: auc_score: 0.7391606439194465
# [[15733     1]
#  [  839     1]]
# (16574, 5) (16574,) (16574, 5) (16574,)
# ensemble: auc_score: 0.618880707233955
# [[10072  5662]
#  [  338   502]]
# ensemble score train set:  0.6379872088813805
# ensemble: auc_score: 0.618880707233955
# [[10072  5662]
#  [  338   502]]
# ensemble score test set:  0.6379872088813805
# Optimization terminated successfully.
#          Current function value: 0.182202
#          Iterations 7
# UKB_hierarchical_quicknat_seg_iou: auc_score: 0.7393361056129583
# [[15733     1]
#  [  839     1]]
# (16574, 7) (16574,) (16574, 7) (16574,)
# ensemble: auc_score: 0.6208475579121949
# [[9291 6443]
#  [ 293  547]]
# ensemble score train set:  0.5935803065041632
# ensemble: auc_score: 0.6208475579121949
# [[9291 6443]
#  [ 293  547]]
# ensemble score test set:  0.5935803065041632
# UKB_hierarchical_quicknat_csv_feats: auc_score: 0.7391670752449957
# [[15733     1]
#  [  839     1]]
# (16574, 5) (16574,) (16574, 5) (16574,)
# ensemble: auc_score: 0.623017865465749
# [[10633  5101]
#  [  361   479]]
# ensemble score train set:  0.6704476891516834
# ensemble: auc_score: 0.623017865465749
# [[10633  5101]
#  [  361   479]]
# ensemble score test set:  0.6704476891516834
# dataset_UKB_processed
# <style  type="text/css" >
#     #T_95958ca2_16b7_11ea_af61_cd32309eb88erow0_col0 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow0_col1 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow0_col5 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow0_col7 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow0_col8 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow0_col9 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow0_col19 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow1_col0 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow1_col1 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow1_col5 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow1_col7 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow1_col8 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow1_col9 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow1_col15 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow1_col18 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow1_col19 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow2_col0 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow2_col1 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow2_col5 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow2_col7 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow2_col8 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow2_col9 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow2_col15 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow2_col18 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow2_col19 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col0 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col1 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col4 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col5 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col7 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col8 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col9 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col14 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col15 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col18 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow3_col19 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow4_col0 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow4_col1 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow4_col5 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow4_col7 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow4_col8 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow4_col9 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow4_col19 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow5_col0 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow5_col1 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow5_col5 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow5_col7 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow5_col8 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow5_col9 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow5_col19 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col0 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col1 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col5 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col7 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col8 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col9 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col11 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col16 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col18 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow6_col19 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow7_col0 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow7_col1 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow7_col4 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow7_col5 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow7_col7 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow7_col8 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow7_col9 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow7_col14 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow7_col19 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow8_col0 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow8_col1 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow8_col5 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow8_col7 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow8_col8 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow8_col9 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow8_col19 {
#             background-color :  yellow;
#         }    #T_95958ca2_16b7_11ea_af61_cd32309eb88erow9_co

# %% [markdown]
# # Regularised Group Feats (eq 4)

# %%
feats = basic_feats
dicts = {}
anova_test_dicts = {}
for model, df in dfs.items():
#     
#     df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver'])
#     df = df.fillna(0)

        
    dicts[model] = {}
    target_cols = ['seg_spleen_normalised', 'seg_liver_normalised']
    for target_col in target_cols:
#     #     Equation 1 process
#         feats_string = make_feature_string(basic_feats, ['sex', 'diabetes_status'])
#         p_values, statsmodel = normal_group_fit(df, target_col, feats_string)
#         dicts[model][target_col] = p_values

    #     Equation 2 process
        feats = basic_feats + ['diabetes_status']
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = normal_group_fit(df, target_col, feats_string)
        regression_plot(y_yp, f'{model}_{target_col}_csv-feats')
        dicts[model][target_col+'_with_csv_feats'] = p_values

        if 'dataset' in model:
#             print('dataset cannot be processed!')
            continue
    
    #     Equation 3 process
        if target_col == 'seg_spleen_normalised':
            iou_feat = ['iou_spleen']
        else:
            iou_feat = ['iou_liver']
        feats = basic_feats + [ 'diabetes_status'] + iou_feat
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = normal_group_fit(df, target_col, feats_string)
        regression_plot(y_yp, f'{model}_{target_col}_seg_iou')
        dicts[model][target_col+'_with_seg_and_iou'] = p_values

    #     Equation 4 process
        feats = basic_feats + [ 'diabetes_status']
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = weighted_group_feats(df, target_col, feats_string, iou_feat[0])
        regression_plot(y_yp, f'{model}_{target_col}_seg_reg_iou')
        dicts[model][target_col+'_with_regularised_seg_volumes'] = p_values

p_value_df = df_from_nested_dicts(dicts).T
p_value_df.to_csv('to_seg.csv')
p_value_df_styler = highlight_significance(p_value_df, 0.05)
p_value_df_styler
# Out:
# full_bayesian_0dot01_seg_spleen_normalised_csv-feats
# full_bayesian_0dot01_seg_spleen_normalised_seg_iou
# full_bayesian_0dot01_seg_spleen_normalised_seg_reg_iou
# full_bayesian_0dot01_seg_liver_normalised_csv-feats
# full_bayesian_0dot01_seg_liver_normalised_seg_iou
# full_bayesian_0dot01_seg_liver_normalised_seg_reg_iou
# MC_dropout_quicknat_seg_spleen_normalised_csv-feats
# MC_dropout_quicknat_seg_spleen_normalised_seg_iou
# MC_dropout_quicknat_seg_spleen_normalised_seg_reg_iou
# MC_dropout_quicknat_seg_liver_normalised_csv-feats
# MC_dropout_quicknat_seg_liver_normalised_seg_iou
# MC_dropout_quicknat_seg_liver_normalised_seg_reg_iou
# probabilistic_quicknat_seg_spleen_normalised_csv-feats
# probabilistic_quicknat_seg_spleen_normalised_seg_iou
# probabilistic_quicknat_seg_spleen_normalised_seg_reg_iou
# probabilistic_quicknat_seg_liver_normalised_csv-feats
# probabilistic_quicknat_seg_liver_normalised_seg_iou
# probabilistic_quicknat_seg_liver_normalised_seg_reg_iou
# hierarchical_quicknat_seg_spleen_normalised_csv-feats
# hierarchical_quicknat_seg_spleen_normalised_seg_iou
# hierarchical_quicknat_seg_spleen_normalised_seg_reg_iou
# hierarchical_quicknat_seg_liver_normalised_csv-feats
# hierarchical_quicknat_seg_liver_normalised_seg_iou
# hierarchical_quicknat_seg_liver_normalised_seg_reg_iou
# dataset_KORA_processed_seg_spleen_normalised_csv-feats
# dataset_KORA_processed_seg_liver_normalised_csv-feats
# <style  type="text/css" >
#     #T_35c603ec_16b7_11ea_af61_cd32309eb88erow0_col1 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow0_col2 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow0_col6 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow0_col7 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow0_col8 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow0_col9 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow0_col10 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow0_col11 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col1 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col2 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col5 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col6 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col7 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col8 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col9 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col10 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col11 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow1_col14 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow2_col1 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow2_col2 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow2_col6 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow2_col7 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow2_col8 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow2_col9 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow2_col10 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow2_col11 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow3_col1 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow3_col2 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow3_col6 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow3_col7 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow3_col8 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow3_col9 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow3_col10 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow3_col11 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col0 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col2 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col5 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col6 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col7 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col8 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col9 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col10 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col11 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow4_col12 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow5_col0 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow5_col1 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow5_col2 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow5_col6 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow5_col7 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow5_col8 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow5_col9 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow5_col10 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow5_col11 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow6_col1 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow6_col2 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow6_col5 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow6_col7 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow6_col8 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow6_col9 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow6_col10 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow6_col11 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col1 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col2 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col4 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col5 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col7 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col8 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col9 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col10 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col11 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow7_col14 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow8_col1 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow8_col2 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow8_col5 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow8_col7 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow8_col8 {
#             background-color :  yellow;
#         }    #T_35c603ec_16b7_11ea_af61_cd32309eb88erow8_col

# %%
feats = basic_feats
dicts = {}
anova_test_dicts = {}
for model, df in dfs_ukb.items():
#     
#     df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver'])
#     df = df.fillna(0)

    

    if 'UKB' not in model:
#         print('dataset cannot be processed!')
        continue
        
    dicts[model] = {}
    target_cols = ['seg_spleen_normalised', 'seg_liver_normalised']
    for target_col in target_cols:
    #     Equation 1 process
        feats = basic_feats + ['diabetes_status']
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = normal_group_fit(df, target_col, feats_string)
        regression_plot(y_yp, f'{model}_{target_col}')
        dicts[model][target_col] = p_values

#     #     Equation 2 process
#         feats = basic_feats + ['diabetes_status']
#         feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
#         p_values, statsmodel = normal_group_fit(df, target_col, feats_string)
#         dicts[model][target_col+'_with_seg_volumes'] = p_values

    #     Equation 3 process
        if 'dataset' in model:
            print('dataset cannot be processed!')
            continue
        if target_col == 'seg_spleen_normalised':
            iou_feat = ['iou_spleen']
        else:
            iou_feat = ['iou_liver']
        feats = basic_feats + [ 'diabetes_status'] + iou_feat
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = normal_group_fit(df, target_col, feats_string)
        regression_plot(y_yp, f'{model}_{target_col}_seg_iou')
        dicts[model][target_col+'_with_iou'] = p_values

    #     Equation 4 process
        feats = basic_feats + [ 'diabetes_status']
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = weighted_group_feats(df, target_col, feats_string, iou_feat[0])
        regression_plot(y_yp, f'{model}_{target_col}_seg_reg_iou')
        dicts[model][target_col+'_with_regularised_seg_volumes'] = p_values

p_value_df = df_from_nested_dicts(dicts).T
p_value_df.to_csv('to_seg.csv')
p_value_df_styler = highlight_significance(p_value_df, 0.05)
p_value_df_styler
# Out:
# UKB_MC_dropout_quicknat_seg_spleen_normalised
# UKB_MC_dropout_quicknat_seg_spleen_normalised_seg_iou
# UKB_MC_dropout_quicknat_seg_spleen_normalised_seg_reg_iou
# UKB_MC_dropout_quicknat_seg_liver_normalised
# UKB_MC_dropout_quicknat_seg_liver_normalised_seg_iou
# UKB_MC_dropout_quicknat_seg_liver_normalised_seg_reg_iou
# UKB_probabilistic_quicknat_seg_spleen_normalised
# UKB_probabilistic_quicknat_seg_spleen_normalised_seg_iou
# UKB_probabilistic_quicknat_seg_spleen_normalised_seg_reg_iou
# UKB_probabilistic_quicknat_seg_liver_normalised
# UKB_probabilistic_quicknat_seg_liver_normalised_seg_iou
# UKB_probabilistic_quicknat_seg_liver_normalised_seg_reg_iou
# UKB_hierarchical_quicknat_seg_spleen_normalised
# UKB_hierarchical_quicknat_seg_spleen_normalised_seg_iou
# UKB_hierarchical_quicknat_seg_spleen_normalised_seg_reg_iou
# UKB_hierarchical_quicknat_seg_liver_normalised
# UKB_hierarchical_quicknat_seg_liver_normalised_seg_iou
# UKB_hierarchical_quicknat_seg_liver_normalised_seg_reg_iou
# dataset_UKB_processed_seg_spleen_normalised
# dataset cannot be processed!
# dataset_UKB_processed_seg_liver_normalised
# dataset cannot be processed!
# <style  type="text/css" >
#     #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col1 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col2 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col3 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col4 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col6 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col7 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col8 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col9 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col10 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col11 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow0_col16 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col1 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col2 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col3 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col5 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col6 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col7 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col8 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col9 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col10 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col11 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow1_col14 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col1 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col2 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col3 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col4 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col6 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col7 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col8 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col9 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col10 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col11 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow2_col16 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col0 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col1 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col2 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col3 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col4 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col6 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col7 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col8 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col9 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col10 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col11 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow3_col16 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col0 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col1 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col2 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col3 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col4 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col6 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col7 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col8 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col9 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col10 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col11 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col12 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow4_col16 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col0 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col1 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col2 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col3 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col4 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col6 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col7 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col8 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col9 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col10 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col11 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow5_col16 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow6_col1 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow6_col3 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow6_col4 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow6_col7 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow6_col8 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow6_col9 {
#             background-color :  yellow;
#         }    #T_3b49c7e0_16b7_11ea_af61_cd32309eb88erow6_col
