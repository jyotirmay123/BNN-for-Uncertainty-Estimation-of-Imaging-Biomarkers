# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import glob
import nibabel as nb
import itertools
import json
import sys
import statsmodels.api as sm
from statsmodels.formula.api import ols, wls
from statsmodels.formula.api import mixedlm
from patsy.contrasts import Treatment

from scipy import stats
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from statsmodels.iolib.table import (SimpleTable, default_txt_fmt)
from statsmodels.discrete.discrete_model import Probit, MNLogit
from statsmodels.tools import add_constant
from sklearn.feature_selection import SelectKBest, SelectPercentile, SelectFdr
from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn import metrics

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler


import seaborn as sns
sns.set(style="whitegrid")

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
np.random.seed(1024)

# %%
base_dir = '/home/abhijit/Jyotirmay/my_thesis'
basic_feats = ['age', 'sex', 'bmi_numeric']
normalised_basic_feats = ['age_normalised', 'sex', 'bmi_numeric_normalised']
spleen_sample_cols = ['0_spleen','1_spleen','2_spleen','3_spleen','4_spleen','5_spleen','6_spleen','7_spleen','8_spleen','9_spleen']
liver_sample_cols = ['0_liver','1_liver','2_liver','3_liver','4_liver','5_liver','6_liver','7_liver','8_liver','9_liver']
vols_feat = ['seg_liver', 'seg_spleen']
iou_feats = ['iou_spleen', 'iou_liver', 'iou_mean']
selected_model_feats = basic_feats + spleen_sample_cols + liver_sample_cols + vols_feat + iou_feats + ['volume_id', 'diabetes_status'] #+ ['iou_dot_seg_spleen_normalised', 'iou_dot_seg_liver_normalised']
selected_dataset_feats = basic_feats +  ['volume_id', 'diabetes_status'] + vols_feat
all_paths = [
#     {'full_bayesian': './projects/full_bayesian/reports/full_bayesian_KORA_v2/KORA/10_1571866968.4002764_concat_report_final.csv'},
    {'full_bayesian_0dot01': './projects/full_bayesian/reports/full_bayesian_KORA_v4/KORA/10_1572514598.527084_concat_report_final.csv'},
    {'MC_dropout_quicknat': './projects/MC_dropout_quicknat/reports/MC_dropout_quicknat_KORA_v2/KORA/10_1572006141.7793334_concat_report_final.csv'}, 
    {'probabilistic_quicknat': './projects/probabilistic_quicknat/reports/probabilistic_quicknat_KORA_v2/KORA/10_1571996796.7963011_concat_report_final.csv'}, 
    {'hierarchical_quicknat': './projects/hierarchical_quicknat/reports/hierarchical_quicknat_KORA_v2/KORA/10_1571905560.9377904_concat_report_final.csv'},
    {'dataset_KORA_processed': './dataset_groups/whole_body_datasets/KORA/all_processed_True_concat_report_final.csv'},
    {'UKB_MC_dropout_quicknat': './projects/MC_dropout_quicknat/reports/MC_dropout_quicknat_UKB_v2/UKB/0_0.0_concat_report_final.csv'},
    {'UKB_probabilistic_quicknat': './projects/probabilistic_quicknat/reports/probabilistic_quicknat_UKB_v2/UKB/10_1573834823.1121247_concat_report_final.csv'},
    {'UKB_hierarchical_quicknat': './projects/hierarchical_quicknat/reports/hierarchical_quicknat_UKB_v2/UKB/10_1574308007.2486243_concat_report_final.csv'},
    {'dataset_UKB_processed': './dataset_groups/whole_body_datasets/UKB/all_processed_True_concat_report_final.csv'}
]

ukb_paths = [
    {'MC_dropout_quicknat': './projects/MC_dropout_quicknat/reports/MC_dropout_quicknat_UKB_v2/UKB/0_0.0_concat_report_final.csv'},
    {'probabilistic_quicknat': './projects/probabilistic_quicknat/reports/probabilistic_quicknat_UKB_v2/UKB/10_1573834823.1121247_concat_report_final.csv'}
]

model_report_paths = {key:val for d in all_paths for key,val in d.items()}
# ukb_model_report_paths = {key:val for d in ukb_paths for key,val in d.items()}

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

def transform_to_categorical(df, categorical_features_list):
    for f in categorical_features_list:
        dfDummies = pd.get_dummies(df[f], prefix = f)
        df = pd.concat([df, dfDummies], axis=1)
    return df

def rename(df, cols_map=None):
    if cols_map is None:
        cols_map =  {'bmi-numeric':'bmi_numeric', 'blood-pressure-diastolic':'blood_pressure_diastolic', 'blood-pressure-systolic':'blood_pressure_systolic',
             'cholesterol-hdl':'cholesterol_hdl', 'cholesterol-ldl':'cholesterol_ldl', 'cholesterol-total':'cholesterol_total',
             'mri-liver-fat-artifacts':'mri_liver_fat_artifacts', 'mri-liver-fat-lobus-dexter':'mri_liver_fat_lobus_dexter', 
              'mri-liver-fat-lobus-sinister':'mri_liver_fat_lobus_sinister', 'mri-liver-fat-portal-vein':'mri_liver_fat_portal_vein',
             'meds-lipoprotein-lowering':'meds_lipoprotein_lowering', 'meds-antihypertensive':'meds_antihypertensive',
              'smoker_non-smoker':'smoker_non_smoker','alcohol-g/day':'alcohol_g_day'}
    df.rename(columns=cols_map, inplace=True)
    return df

def z_score_column_normalise(df, column_list):
    normalised_cols_map = {}
    for column in column_list:
        normalised_cols_map[column] = column+'_normalised'
#         df[normalised_cols_map[column]] = (df[column] - df[column].mean())/df[column].std(ddof=0)
        df[normalised_cols_map[column]] = (df[column] - df[column].min())/ (df[column].max() - df[column].min())
    return df, normalised_cols_map

def z_score_group_normalise(df, cols_to_normalise):
    normalised_cols_map = {}
    group_cols_value = df[cols_to_normalise].values
    mean, std = np.mean(group_cols_value), np.std(group_cols_value, ddof=0)
    for column in cols_to_normalise:
        normalised_cols_map[column] = 'normalised_'+column
        df[normalised_cols_map[column]] = (df[column] - mean)/std
    return df, normalised_cols_map

def pre_process_for_mlm(df, to_be_transpose_cols, value_name):
    cols = list(df.columns)
    cols_without_tobe_transposed_cols = list(set(cols) - set(to_be_transpose_cols))
    df = df.melt(id_vars=cols_without_tobe_transposed_cols, 
            value_vars=to_be_transpose_cols, 
            value_name=value_name)

    return df

def model_evaluation_matrics(file_paths_dict, cols_to_fetch):
    dicts = {}
    for model, path in file_paths_dict.items():
        if 'dataset' in model:
            continue
        df = pd.read_csv(path)
        dicts[model] = df[cols_to_fetch].iloc[1:].mean()
    return dicts

def individual_feature_stats(feats, df, target_col, categorical_feats=['diabetes_status', 'sex']):
    p_values = {}
    for f in feats:
        try:
            features_string = make_feature_string([f], categorical_feats)
            fii = ols(f'{target_col} ~ {features_string}', df).fit()
            feat_dict = fii.pvalues.to_dict()
            coeffs = fii.params
        
            for k, v in feat_dict.items():
                orig_key = k
                if k == 'Intercept':
                    k = f+'_Intercept'
                p_values[k] = v

                p_values[k+'_coeff'] = coeffs[orig_key]
            p_values['fitting_score'] = fii.rsquared
        except Exception as e:
            print(e)

    return p_values


def make_feature_string(feats, categorical_cols=[]):
    feat_str = '1+'
    for c_col in categorical_cols:
        if type(c_col) is tuple:
            if c_col[0] not in feats:
#                 print(f'{c_col} is not present in given feature list, SKIPPING IT!')
                continue
            feat_str += f'C({c_col[0]}, Treatment(reference={c_col[1]}))+'
            c_col = c_col[0]
        else:
            if c_col not in feats:
#                 print(f'{c_col} is not present in given feature list, SKIPPING IT!')
                continue
            feat_str += f'C({c_col}, Treatment)+'
        feats.remove(c_col)
    
    other_feats_str = '+'.join(feats)
    if other_feats_str is '':
        final_feat_str = feat_str[:-1]
    else:
        final_feat_str = feat_str + other_feats_str

    return final_feat_str
    



def normal_mixed_effect_model(df, target_col, features_string, group_col, L1_wt=None):
    if L1_wt is None:
        model = mixedlm(f'{target_col} ~ {features_string}', df, groups=df[group_col]).fit()
    else:
        model = mixedlm(f'{target_col} ~ {features_string}', df, groups=df[group_col]).fit_regularized(L1_wt=L1_wt)
    return model

def anova_test(ols_model):
    anova_stats = sm.stats.anova_lm(ols_model)
    return anova_stats

def df_from_nested_dicts(dicts):
    df = pd.concat({k+'_'+kk: pd.concat({kk:pd.DataFrame(vv, index=[0]).T}, axis=1) for k, v in dicts.items() for kk, vv in v.items()}, axis=1)
    return df

def df_from_nested_dicts_group(dicts):
    df = pd.concat({k+'_'+kk: pd.concat({kk:pd.DataFrame(vv, index=[0]).T}, axis=1) for k, v in dicts.items() for kk, vv in v.items()}, axis=1)
    return df

def highlight_significance(df, threshold=0.05):
    return df.style.applymap(lambda x: 'background-color : yellow' if x==True or x<threshold else '')


def discrete_group_feature_stats(feats, df, target_col, categorical_feats=['diabetes_status', 'sex'], is_classification=False):
    p_values = {}
    try:
#             features_string = f'1+C({f}, Treatment)' if f in categorical_feats else f'1+{f}'
        x = df[feats]
        y = df[target_col]
            
#         scaler = StandardScaler().fit(x)
#         x = scaler.transform(x)
    
        x = add_constant(x)
        model = Probit(y, x)
        fii = model.fit()
        predicted = fii.predict(x)
#         fig, axes = plt.subplots(1, 1, figsize=(14, 6))
#         sample_weight_constant = np.ones(len(x))
#         plot_decision_function(fii, axes,sample_weight_constant, 'with no weights')
#             print(model.pdf(x))
#         fii_ = fii.get_margeff()
#         print(fii.summary())
# #         print(fii_.summary())
        feat_dict = fii.pvalues.to_dict()
        coeffs = fii.params
        
        for k, v in feat_dict.items():
            p_values[k] = v
            p_values[k+'_coeff'] = coeffs[k]

        p_values['aic'] = fii.aic
        p_values['bic'] = fii.bic
        p_values['psuedo_r2'] = fii.prsquared
    except Exception as e:
        print('ERROR:', e)

    return p_values, fii, (y, predicted)

# def weighted_group_feats(df, target_col, features_string, alpha_col):
#     alpha = df[alpha_col].values
#     model = wls(f'{target_col} ~ {features_string}', df, weights=(1/(1-alpha))).fit()
#     return model

def discrete_weighted_group_feats(df, target_col, feats, alpha_col):
    p_values = {}
    alpha = df[alpha_col].values
    x = df[feats]
    y = df[target_col]
    
#     scaler = StandardScaler().fit(x)
#     x = scaler.transform(x)
    
    x = add_constant(x)
    fii = sm.GLM(y, x, family=sm.families.Binomial(sm.families.links.probit), missing='drop', var_weights=alpha).fit()
    predicted = fii.predict(x)
#     print(fii.summary())
#     print(fii.to_dict())
#     fig, axes = plt.subplots(1, 1, figsize=(14, 6))
#     plot_decision_function(fii, alpha, axes, 'with weights')
    feat_dict = fii.pvalues.to_dict()
    coeffs = fii.params

    for k, v in feat_dict.items():
        p_values[k] = v
        p_values[k+'_coeff'] = coeffs[k]

    p_values['aic'] = fii.aic
    p_values['bic'] = fii.bic
    sst_val = sum(map(lambda x: np.power(x,2),y-np.mean(y))) 
    sse_val = sum(map(lambda x: np.power(x,2),fii.resid_response)) 
    r2 = 1-(sse_val/sst_val)
    p_values['psuedo_r2'] = r2
    return p_values, fii, (y, predicted)

def normal_group_fit(df, target_col, features_string):
    p_values = {}
    fii = ols(f'{target_col} ~ {features_string}', df).fit()
    y = df[target_col].values
    predicted = fii.predict(df)
    feat_dict = fii.pvalues.to_dict()
    coeffs = fii.params

    for k, v in feat_dict.items():
        p_values[k] = v
        p_values[k+'_coeff'] = coeffs[k]

    p_values['aic'] = fii.aic
    p_values['bic'] = fii.bic
    p_values['psuedo_r2'] = fii.rsquared
    return p_values, fii, (y, predicted)

def weighted_group_feats(df, target_col, features_string, alpha_col):
    p_values = {}
    alpha = df[alpha_col].values
    fii = wls(f'{target_col} ~ {features_string}', df, weights=alpha).fit()
    y = df[target_col].values
    predicted = fii.predict(df)
    feat_dict = fii.pvalues.to_dict()
    coeffs = fii.params
    
    for k, v in feat_dict.items():
        p_values[k] = v
        p_values[k+'_coeff'] = coeffs[k]

    p_values['aic'] = fii.aic
    p_values['bic'] = fii.bic
    p_values['psuedo_r2'] = fii.rsquared
    return p_values, fii, (y, predicted)

# %%
def normalise_iou(df):
    for iou_col in ['iou_spleen', 'iou_liver', 'iou_mean']:
        iou = df[iou_col]
#         iou = (iou - iou.mean())/iou.std(ddof=0)
        iou = (iou - iou.min()) / (iou.max() - iou.min())
        df[f'{iou_col}_normalised'] = iou
#     df['iou_mean_normalised'] = (df['iou_spleen_normalised'] + df['iou_liver_normalised']) / 2
    return df

# for model, path in model_report_paths.items():
#     if 'dataset' in model:
#         continue
#     print(model)
#     dfk = pd.read_csv(model_report_paths[model])
#     iou = dfk['iou_spleen']
    
#     print(iou.max(), iou.mean(), iou.min(), iou.std())

#     iou.plot.kde()
#     plt.show()
#     iou = (iou - iou.min()) / (iou.max() - iou.min())
#     print(iou.max(), iou.mean(), iou.min(), iou.std())
#     iou.plot.kde()
#     plt.show()
# #     s = np.random.normal(iou.mean(), 10*iou.std(), 1000)
# #     count, bins, ignored = plt.hist(s, 30, density=True)
# #     plt.show()

# %%
# sst_val = sum(map(lambda x: np.power(x,2),y-np.mean(y))) 
# sse_val = sum(map(lambda x: np.power(x,2),model.resid_response)) 
# r2 = 1-(sse_val/sst_val)

# %%
# r2

# %%
# print(logmodel.resid_deviance, logmodel.null_deviance, model.resid_response, logmodel.resid_response)

# %%
def plot_pdf(good_pdf, bad_pdf, ax):
    ax.fill(x, good_pdf, "g", alpha=0.5)
    ax.fill(x, bad_pdf,"r", alpha=0.5)
    ax.set_xlim([0,1])
    ax.set_ylim([0,5])
    ax.set_title("Probability Distribution", fontsize=14)
    ax.set_ylabel('Counts', fontsize=12)
    ax.set_xlabel('P(X="bad")', fontsize=12)
    ax.legend(["good","bad"])

def auc_roc(y_yp, title):
    y, predicted = y_yp
    y_p = np.where(predicted > 0.5, 1, 0)
    labels = [0, 1]
    y_1_mask = np.where(y==1, True, False)
    y_0_mask = np.where(y==0, True, False)
    xs = [predicted[y_0_mask], predicted[y_1_mask]]

    fig, ax0 = plt.subplots(nrows=1, ncols=1)
    colors = ['red','blue']
    ax0.hist(xs, 10, normed=1, histtype='bar', color=colors, label=labels)
    ax0.legend(prop={'size': 10})
    ax0.set_title('bars with legend')
    plt.show()
    
   
    fpr, tpr, thresholds = metrics.roc_curve(y, predicted, pos_label=1)
    auc_score = metrics.roc_auc_score(y, predicted)
 
#     f1_score = metrics.f1_score(y, y_p, labels=labels)
    print(f'{title}: auc_score: {auc_score}')
#     plt.scatter(predicted, y)
#     plt.show()
    plt.plot(fpr, tpr)
    plt.show()
#     print(list(y))
#     print(predicted)
    
#     print(y_p)
    
    cm = confusion_matrix(y, y_p, labels)
    print(cm)
#     fig = plt.figure()
#     ax = fig.add_subplot(111)
#     cax = ax.matshow(cm)
#     plt.title('Confusion matrix of the classifier')
#     fig.colorbar(cax)
#     ax.set_xticklabels([''] + labels)
#     ax.set_yticklabels([''] + labels)
#     plt.xlabel('Predicted')
#     plt.ylabel('True')
#     plt.show()
    
#     unique_elements, counts_elements = np.unique(predicted, return_counts=True)
#     plt.hist(predicted, bins=20)
#     plt.bar(unique_elements, counts_elements)
#     plt.show()
    
#     print(disp)
#     disp.ax_.set_title(title)

#     print(title)
#     print(disp.confusion_matrix)
#     print(f'{title}:::  fpr: {fpr}, tpr: {tpr}, threshold: {thresholds}')
    return auc_score, 1

def regression_plot(y_yp, title=''):
    y, predicted = y_yp
    print(title)
    plt.scatter(predicted, y)
    plt.show()
    
def random_forest_evaluations(df, target_col, feats):
    y = df[target_col]
    x = df[feats]
    kfold_rf = model_selection.KFold(n_splits=10, random_state=10)
    model_rf = RandomForestClassifier(n_estimators=100, max_features=3)
    results_rf = model_selection.cross_val_score(model_rf, x, y, cv=kfold_rf)
    print('Random Forest Out:', results_rf.mean())
    return results_rf.mean()

def bagging_evaluations(df, target_col, feats):
    y = df[target_col]
    x = df[feats]
    kfold = model_selection.KFold(n_splits=10, random_state=10)
    model_1 = BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100, random_state=10)
    results_1 = model_selection.cross_val_score(model_1, x, y, cv=kfold)
    print('Bagging Out:', results_1.mean())
    return results_1.mean()

def sgd_evaluator(df, target_col, feats):
    y = df[target_col]
    x = df[feats]
    kfold_sgb = model_selection.KFold(n_splits=10, random_state=10)
    model_sgb = GradientBoostingClassifier(n_estimators=100, random_state=10)
    results_sgb = model_selection.cross_val_score(model_sgb, x, y, cv=kfold_sgb)
    
    y_p = model_sgb.fit(x, y).predict(x)
    print('model score: ', model_sgb.score(x, y))
    auc_roc((y, y_p), 'sgd')
    print('Stochastic Gradient out:', results_sgb)
    return results_sgb.mean()

def voting_classifier_evaluator(df, target_col, feats, weight_col=None, ensemble=None):
    y = df[target_col]
#     feats = ['age', 'bmi_numeric']
    if weight_col is None:
        x = df[feats]
        weights = None
    else:
        x = df[feats]
        weights = df[weight_col].values
    
#     scaler = StandardScaler().fit(x)
#     x = scaler.transform(x)
    x = add_constant(x)
    
    X_train, X_test, y_train, y_test = x, x, y, y #train_test_split(x, y, test_size=0.33, random_state=10)

   
    if ensemble is None:
        # Lines 2 to 8
        estimators = []
    
#         mod_rf = RandomForestClassifier(n_estimators=100, max_features=3)
#         estimators.append(('rf', mod_rf))
        mod_bagging = BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100, random_state=10)
        estimators.append(('bagging', mod_bagging))
        mod_sgd = GradientBoostingClassifier(n_estimators=100, random_state=10)
        estimators.append(('sgd', mod_sgd))
        mod_lr = LogisticRegression()
        estimators.append(('logistic', mod_lr))
        mod_dt = DecisionTreeClassifier()
        estimators.append(('cart', mod_dt))
        mod_sv = SVC()
        estimators.append(('svm', mod_sv))

#         # Lines 9 to 11
#         if weight_col is not None:
#             title = 'With WEIGHTS'
#             weights = X_train[weight_col].values
#             X_train = X_train.drop(columns=[weight_col])
#             X_test = X_test.drop(columns=[weight_col])
#         else:
#             title = 'With NO WEIGHTS'
#             weights = None
      
        ensemble = VotingClassifier(estimators)
#         print(X_train.columns)
        ensemble.fit(X_train, y_train, sample_weight=weights)
    else:
       
        X_train, X_test, y_train, y_test = x, x, y, y
    
#     fig, axes = plt.subplots(1, 1, figsize=(14, 6))
#     if weights is None:
#         weights = np.ones(len(X_train))
#     plot_decision_function(ensemble, weights, axes, title, X_train.values, y_train.values)
    print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
#         print(ensemble)
#     auc_roc((y_train, ensemble.predict(X_train)), 'ensemble')
#     print('ensemble score train set: ',ensemble.score(X_train, y_train))
    auc, _ = auc_roc((y_test, ensemble.predict(X_test)), 'ensemble')
#     print('ensemble score test set: ',ensemble.score(X_test, y_test))
#      kfold_vc = model_selection.KFold(n_splits=10, random_state=10)
#     results_vc = model_selection.cross_val_score(ensemble, X_test, y_test, cv=kfold_vc)
#     print('Voting Classifier out many mean:', results_vc.mean())
# 
    return ensemble.score(X_test, y_test), ensemble.score(X_test, y_test, sample_weight=weights), ensemble, auc

def plot_decision_function(classifier, sample_weight, axis, title, X, y):
    # plot the decision function
    xx, yy = np.meshgrid(np.linspace(-4, 5, 500), np.linspace(-4, 5, 500))

    Z = classifier.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # plot the line, the points, and the nearest vectors to the plane
    axis.contourf(xx, yy, Z, alpha=0.75, cmap=plt.cm.bone)
    axis.scatter(X[:, 0], X[:, 1], c=y, s=100 * sample_weight, alpha=0.9,
                 cmap=plt.cm.bone, edgecolors='black')

    axis.axis('off')
    axis.set_title(title)
    
def aggregate_model_outputs(df, target_col, feats, dicts, model, key, ensemble=None, weights=None):
#     dicts['rf'] = random_forest_evaluations(df, target_col, feats)
#     dicts[model][key]['bagging'] = bagging_evaluations(df, target_col, feats)
#     dicts[model][key]['sgd'] = sgd_evaluator(df, target_col, feats)
    dicts[model][key]['v_scoring'],dicts[model][key]['v_scoring_with_weight'], ensemble, dicts[model][key]['v_auc'] = voting_classifier_evaluator(df, target_col, feats, weights, ensemble)
    
    return dicts, ensemble

# %%
cols_to_fetch = ['sncc', 'ged', 'iou_spleen', 'iou_liver', 'dice_spleen',
       'dice_liver', 'surface_distance_avg_spleen', 'surface_distance_avg_liver']
dicts = model_evaluation_matrics(model_report_paths, cols_to_fetch)
df_model_eval = pd.DataFrame.from_dict(dicts)
df_model_eval = df_model_eval.T
# df_model_eval.columns = cols_to_fetch
df_model_eval
# Out:
#                                 sncc       ged  iou_spleen  iou_liver  \
# full_bayesian_0dot01        0.440058  0.195726    0.778430   0.843838
# MC_dropout_quicknat         0.400336  0.166126    0.821658   0.878743
# probabilistic_quicknat      0.164762  0.228213    0.988126   0.992441
# hierarchical_quicknat       0.188499  0.209206    0.983803   0.989027
# UKB_MC_dropout_quicknat          NaN       NaN    0.730973   0.807269
# UKB_probabilistic_quicknat       NaN       NaN    0.965202   0.980590
# UKB_hierarchical_quicknat        NaN       NaN    0.935690   0.939154
#
#                             dice_spleen  dice_liver  \
# full_bayesian_0dot01           0.876213    0.921414
# MC_dropout_quicknat            0.897251    0.937764
# probabilistic_quicknat         0.873734    0.925382
# hierarchical_quicknat          0.883031    0.932817
# UKB_MC_dropout_quicknat             NaN         NaN
# UKB_probabilistic_quicknat          NaN         NaN
# UKB_hierarchical_quicknat           NaN         NaN
#
#                             surface_distance_avg_spleen  \
# full_bayesian_0dot01                           0.878335
# MC_dropout_quicknat                            0.915783
# probabilistic_quicknat                         0.875181
# hierarchical_quicknat                          0.897130
# UKB_MC_dropout_quicknat                             NaN
# UKB_probabilistic_quicknat                          NaN
# UKB_hierarchical_quicknat                           NaN
#
#                             surface_distance_avg_liver
# full_bayesian_0dot01                          0.817338
# MC_dropout_quicknat                           0.871014
# probabilistic_quicknat                        0.827286
# hierarchical_quicknat                         0.854920
# UKB_MC_dropout_quicknat                            NaN
# UKB_probabilistic_quicknat                         NaN
# UKB_hierarchical_quicknat                          NaN

# %% [markdown]
# # Post Process reports

# %%
dfs = {}
common_vols = None

for model, path in model_report_paths.items():
    if 'dataset' in model:
        continue
    if 'UKB' in model:
        continue
    print(model)
    df = pd.read_csv(path)
    df = rename(df)
    dfs[model] = df
    vols = df[(df['iou_mean']>0.51) & (df['iou_spleen'] != 1.0) & (df['iou_liver'] != 1.0)].volume_id.values
    if common_vols is None:
        common_vols = vols
    else:
        common_vols = np.intersect1d(common_vols, vols)
    print(common_vols.shape)

df_dataset = pd.read_csv(model_report_paths['dataset_KORA_processed'])
df_dataset = rename(df_dataset)
dfs['dataset_KORA_processed']  = df_dataset

for model, df in dfs.items():
    if 'dataset' in model:
        selected_feats = selected_dataset_feats
    else:
        selected_feats = selected_model_feats #+ ['iou_spleen_normalised', 'iou_liver_normalised', 'iou_mean_normalised']
     
        
    df = df[df.volume_id.isin(common_vols)][selected_feats]
    df['seg_spleen_bmi_normalised'] = df['seg_spleen'] / df['bmi_numeric']
    df['seg_liver_bmi_normalised'] = df['seg_liver'] / df['bmi_numeric']
    df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver', 'age', 'bmi_numeric','seg_liver_bmi_normalised', 'seg_spleen_bmi_normalised'])
    if 'dataset' not in model:
        df['iou_dot_seg_spleen'] = df['iou_spleen'] * df['seg_spleen']
        df['iou_dot_seg_liver'] = df['iou_liver'] * df['seg_liver']
        df, _ =  z_score_column_normalise(df, ['iou_dot_seg_spleen', 'iou_dot_seg_liver'])
        df = normalise_iou(df)
#         print(df[])
    dfs[model] = df
    print('model shape:', dfs[model].shape)

## Change pre-diabetic state to diabetic
for model, df in dfs.items():
    df.loc[df['diabetes_status']==2, 'diabetes_status'] = 1
    dfs[model] = df
    dfs[model].to_csv(f'final_feats_{model}.csv', index=False)
# Out:
# full_bayesian_0dot01
# (148,)
# MC_dropout_quicknat
# (147,)
# probabilistic_quicknat
# (147,)
# hierarchical_quicknat
# (147,)
# model shape: (147, 45)
# model shape: (147, 45)
# model shape: (147, 45)
# model shape: (147, 45)
# model shape: (147, 15)

# %%
dfs_ukb = {}
common_vols = None

for model, path in model_report_paths.items():
    if 'dataset' in model:
        continue
    if 'UKB' not in model:
        continue
    print(model)
    df = pd.read_csv(path)
    df = rename(df)
    dfs_ukb[model] = df
    vols = df[(df['iou_mean']>0.51) & (df['iou_spleen'] != 1.0) & (df['iou_liver'] != 1.0)].volume_id.values
    if common_vols is None:
        common_vols = vols
    else:
        common_vols = np.intersect1d(common_vols, vols)
    print(common_vols.shape)

df_dataset = pd.read_csv(model_report_paths['dataset_UKB_processed'])
# common_vols = np.intersect1d(common_vols, df_dataset.volume_id.values)
df_dataset = rename(df_dataset)
dfs_ukb['dataset_UKB_processed']  = df_dataset

for model, df in dfs_ukb.items():
    if 'dataset' in model:
        selected_feats = selected_dataset_feats
    else:
        selected_feats = selected_model_feats #+ ['iou_spleen_normalised', 'iou_liver_normalised', 'iou_mean_normalised']
        
    df = df[df.volume_id.isin(common_vols)][selected_feats]
    df['seg_spleen_bmi_normalised'] = df['seg_spleen'] / df['bmi_numeric']
    df['seg_liver_bmi_normalised'] = df['seg_liver'] / df['bmi_numeric']
    df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver', 'age', 'bmi_numeric'])
    if 'dataset' not in model:
        df['iou_dot_seg_spleen'] = df['iou_spleen'] * df['seg_spleen']
        df['iou_dot_seg_liver'] = df['iou_liver'] * df['seg_liver']
        df, _ =  z_score_column_normalise(df, ['iou_dot_seg_spleen', 'iou_dot_seg_liver'])
        df = normalise_iou(df)
    dfs_ukb[model] = df
    print('model shape:', dfs_ukb[model].shape)
    
# df_dataset = pd.read_csv(model_report_paths['dataset_KORA_processed'])
# df_dataset = rename(df_dataset)
# dfs['dataset_KORA_processed'] = df[df.volume_id.isin(common_vols)][selected_dataset_feats]
# print(dfs['dataset_KORA_processed'].shape)

## Change pre-diabetic state to diabetic
for model, df in dfs_ukb.items():
    df.loc[df['diabetes_status']==2, 'diabetes_status'] = 1
    dfs_ukb[model] = df
    dfs_ukb[model].to_csv(f'final_feats_{model}.csv', index=False)
# Out:
# UKB_MC_dropout_quicknat
# (18201,)
# UKB_probabilistic_quicknat
# (17328,)
# UKB_hierarchical_quicknat
# (16574,)
# model shape: (16574, 43)
# model shape: (16574, 43)
# model shape: (16574, 43)
# model shape: (6, 13)

# %% [markdown]
# # Equations
#
# Eq-1: Diabetes_status = a0 +a1*age + a2*sex + a3*BMI
#
# Eq-2: Diabetes_status = a0 +a1*age + a2*sex + a3*BMI + a4*seg_<spleen|liver>
#
# Eq-3: Diabetes_status = a0 +a1*age + a2*sex + a3*BMI + a4*seg_<spleen|liver> + a5*iou_<spleen|liver>
#
# Eq-4: Diabetes_status = a0 +a1*age + a2*sex + a3*BMI + a4*(iou_<spleen|liver> * seg_<spleen|liver>)
#
# Eq-4: (Diabetes_status == a0 +a1*age + a2*sex + a3*BMI + a4*seg_<spleen|liver>) * iou_<spleen|liver>
#
# // Eq-5: Diabetes_status = a0 +a1*age + a2*sex + a3*BMI +  a4*seg_<spleen|liver>)i

# %% [markdown]
# # Group features (eq 1, eq 2, eq 3 and eq 4)

# %%
feats = basic_feats
dicts = {}
anova_test_dicts = {}
global_kora_models = {}
# basic_feats = normalised_basic_feats
for model, df in dfs.items():
#     
#     df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver'])
#     df = df.fillna(0)

    dicts[model] = {}
    global_kora_models[model] = {}
    target_col = 'diabetes_status'
 
#   Equation 1 process
    p_values, statsmodel, y_yp = discrete_group_feature_stats(basic_feats, df, target_col, ['sex'], True)
#     print(y_yp)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_csv_features')
    dicts[model][target_col] = p_values
    dicts[model][target_col]['auc'] = auc_score
    dicts[model][target_col]['f1'] = f1_score
    dicts, global_kora_models[model]['normal'] = aggregate_model_outputs(df, target_col, basic_feats, dicts, model, target_col)
#     global_kora_models[model]['normal'] = statsmodel
#     for organ in ['spleen', 'liver']:
    organ = 'liver'
#     Equation 2 process
    feats = basic_feats + [ f'seg_{organ}_normalised', f'seg_spleen_normalised']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_{organ}_with_seg_volumes')
    dicts[model][target_col+f'_with_{organ}_seg_volumes'] = p_values
    dicts[model][target_col+f'_with_{organ}_seg_volumes']['auc'] = auc_score
    dicts[model][target_col+f'_with_{organ}_seg_volumes']['f1'] = f1_score
    dicts, global_kora_models[model][f'{organ}_seg'] = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+f'_with_{organ}_seg_volumes')
#     global_kora_models[model][f'{organ}_seg'] = statsmodel
    if 'dataset' in model:
        continue

#     Equation 3 process
    feats = basic_feats + [ f'seg_{organ}_normalised', f'iou_{organ}',  f'seg_spleen_normalised', f'iou_spleen']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_{organ}_with_seg_iou')
    dicts[model][target_col+f'_with_{organ}_seg_and_iou'] = p_values
    dicts[model][target_col+f'_with_{organ}_seg_and_iou']['auc'] = auc_score
    dicts[model][target_col+f'_with_{organ}_seg_and_iou']['f1'] = f1_score
    dicts, global_kora_models[model][f'{organ}_seg_iou'] = aggregate_model_outputs(df, target_col, feats, dicts, model,target_col+f'_with_{organ}_seg_and_iou')
#     global_kora_models[model][f'{organ}_seg_iou'] = statsmodel
#     Equation 3.1 process
    feats = basic_feats + [f'seg_{organ}_normalised' , f'seg_spleen_normalised', f'iou_dot_seg_{organ}_normalised', f'iou_dot_seg_spleen_normalised']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_{organ}_with_seg_dot_iou')
    dicts[model][target_col+f'_with_{organ}_seg_dot_iou'] = p_values
    dicts[model][target_col+f'_with_{organ}_seg_dot_iou']['auc'] = auc_score
    dicts[model][target_col+f'_with_{organ}_seg_dot_iou']['f1'] = f1_score
    dicts, global_kora_models[model][f'{organ}_seg_dot_iou'] = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+f'_with_{organ}_seg_dot_iou')
#     global_kora_models[model][f'{organ}_seg_dot_iou'] = statsmodel


#     Equation 4 process
    feats = basic_feats + [ f'seg_{organ}_normalised', f'seg_spleen_normalised']
    p_values, statsmodel, y_yp = discrete_weighted_group_feats(df, target_col, feats, f'iou_mean')
    auc_score, f1_score = auc_roc(y_yp, f'{model}_{organ}_with_seg_reg_iou')
    dicts[model][target_col+f'_with_{organ}_regularised_seg_volumes'] = p_values
    dicts[model][target_col+f'_with_{organ}_regularised_seg_volumes']['auc'] = auc_score
    dicts[model][target_col+f'_with_{organ}_regularised_seg_volumes']['f1'] = f1_score
    dicts, global_kora_models[model][f'{organ}_seg_reg_iou'] = aggregate_model_outputs(df, target_col, feats,  dicts, model, target_col+f'_with_{organ}_regularised_seg_volumes',None,  f'iou_mean')
#     global_kora_models[model][f'{organ}_seg_reg_iou'] =  statsmodel

    
p_value_df_k = df_from_nested_dicts(dicts).T
p_value_df_styler_k = highlight_significance(p_value_df_k, 0.05)
p_value_df_styler_k
# Out:
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# full_bayesian_0dot01_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (147, 4) (147,) (147, 4) (147,)
# ensemble: auc_score: 0.98
# [[97  0]
#  [ 2 48]]
# Optimization terminated successfully.
#          Current function value: 0.453328
#          Iterations 6
# full_bayesian_0dot01_liver_with_seg_volumes: auc_score: 0.8515463917525773
# [[87 10]
#  [18 32]]
# (147, 6) (147,) (147, 6) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.423270
#          Iterations 6
# full_bayesian_0dot01_liver_with_seg_iou: auc_score: 0.8682474226804124
# [[88  9]
#  [20 30]]
# (147, 8) (147,) (147, 8) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.414348
#          Iterations 6
# full_bayesian_0dot01_liver_with_seg_dot_iou: auc_score: 0.8715463917525773
# [[87 10]
#  [19 31]]
# (147, 8) (147,) (147, 8) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# full_bayesian_0dot01_liver_with_seg_reg_iou: auc_score: 0.8511340206185566
# [[87 10]
#  [17 33]]
# (147, 6) (147,) (147, 6) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# MC_dropout_quicknat_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (147, 4) (147,) (147, 4) (147,)
# ensemble: auc_score: 0.98
# [[97  0]
#  [ 2 48]]
# Optimization terminated successfully.
#          Current function value: 0.438315
#          Iterations 6
# MC_dropout_quicknat_liver_with_seg_volumes: auc_score: 0.86
# [[86 11]
#  [18 32]]
# (147, 6) (147,) (147, 6) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.416056
#          Iterations 7
# MC_dropout_quicknat_liver_with_seg_iou: auc_score: 0.8665979381443298
# [[89  8]
#  [16 34]]
# (147, 8) (147,) (147, 8) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.407386
#          Iterations 7
# MC_dropout_quicknat_liver_with_seg_dot_iou: auc_score: 0.8696907216494846
# [[89  8]
#  [16 34]]
# (147, 8) (147,) (147, 8) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# MC_dropout_quicknat_liver_with_seg_reg_iou: auc_score: 0.8616494845360825
# [[86 11]
#  [18 32]]
# (147, 6) (147,) (147, 6) (147,)
# ensemble: auc_score: 1.0
# [[97  0]
#  [ 0 50]]
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# probabilistic_quicknat_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (147, 4) (147,) (147, 4) (147,)
# ensemble: auc_score: 0.98
# [[97  0]
#  [ 2 48]]
# Optimization terminated successfully.
#          Current function value: 0.446703
#          Iterations 6
# probabilistic_quicknat_liver_with_seg_volumes: auc_score: 0.8560824742268041
# [[87 10]
#  [19 31]]
# (147, 6) (147,) (147, 6) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.418020
#          Iterations 7
# probabilistic_quicknat_liver_with_seg_iou: auc_score: 0.8649484536082473
# [[87 10]
#  [18 32]]
# (147, 8) (147,) (147, 8) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.408547
#          Iterations 7
# probabilistic_quicknat_liver_with_seg_dot_iou: auc_score: 0.8701030927835053
# [[88  9]
#  [16 34]]
# (147, 8) (147,) (147, 8) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# probabilistic_quicknat_liver_with_seg_reg_iou: auc_score: 0.8560824742268041
# [[87 10]
#  [19 31]]
# (147, 6) (147,) (147, 6) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# hierarchical_quicknat_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (147, 4) (147,) (147, 4) (147,)
# ensemble: auc_score: 0.98
# [[97  0]
#  [ 2 48]]
# Optimization terminated successfully.
#          Current function value: 0.447388
#          Iterations 6
# hierarchical_quicknat_liver_with_seg_volumes: auc_score: 0.8579381443298969
# [[87 10]
#  [18 32]]
# (147, 6) (147,) (147, 6) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.426626
#          Iterations 7
# hierarchical_quicknat_liver_with_seg_iou: auc_score: 0.8628865979381443
# [[88  9]
#  [19 31]]
# (147, 8) (147,) (147, 8) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.421687
#          Iterations 7
# hierarchical_quicknat_liver_with_seg_dot_iou: auc_score: 0.865360824742268
# [[88  9]
#  [16 34]]
# (147, 8) (147,) (147, 8) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# hierarchical_quicknat_liver_with_seg_reg_iou: auc_score: 0.8577319587628867
# [[87 10]
#  [18 32]]
# (147, 6) (147,) (147, 6) (147,)
# ensemble: auc_score: 0.99
# [[97  0]
#  [ 1 49]]
# Optimization terminated successfully.
#          Current function value: 0.466512
#          Iterations 6
# dataset_KORA_processed_csv_features: auc_score: 0.8463917525773196
# [[88  9]
#  [19 31]]
# (147, 4) (147,) (147, 4) (147,)
# ensemble: auc_score: 0.98
# [[97  0]
#  [ 2 48]]
# Optimization terminated successfully.
#          Current function value: 0.434546
#          Iterations 6
# dataset_KORA_processed_liver_with_seg_volumes: auc_score: 0.8604123711340206
# [[86 11]
#  [19 31]]
# (147, 6) (147,) (147, 6) (147,)
# ensemble: auc_score: 1.0
# [[97  0]
#  [ 0 50]]
# <style  type="text/css" >
#     #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row0_col0 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row0_col5 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row0_col7 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row0_col8 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row0_col9 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row0_col23 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row0_col25 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row1_col0 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row1_col5 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row1_col7 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row1_col8 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row1_col9 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row1_col22 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row1_col25 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col0 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col5 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col7 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col8 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col9 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col15 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col16 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col19 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col22 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row2_col25 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col0 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col5 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col7 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col8 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col9 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col10 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col11 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col12 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col19 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col21 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col22 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row3_col25 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row4_col0 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row4_col4 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row4_col5 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row4_col7 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row4_col8 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row4_col9 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row4_col22 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row4_col25 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row5_col0 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row5_col5 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row5_col7 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row5_col8 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row5_col9 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row5_col23 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row5_col25 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row6_col0 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row6_col5 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row6_col7 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row6_col8 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row6_col9 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row6_col19 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row6_col22 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row6_col25 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col0 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col5 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col8 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col9 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col15 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col16 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col19 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col21 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col22 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row7_col25 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row8_col0 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row8_col5 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row8_col7 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row8_col8 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row8_col9 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row8_col11 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f54d7row8_col12 {
#             background-color :  yellow;
#         }    #T_f2296564_177b_11ea_b432_f7e2eb8f

# %%
# !pip install shap
# !pip install xgboost

# %% [markdown]
# # Ensemble Techniques

# %%
import shap 
# import xgboost

shap.initjs()
for model, df in dfs.items():
    feats = basic_feats + [ 'seg_spleen_normalised', 'seg_liver_normalised',  f'iou_dot_seg_liver_normalised', f'iou_dot_seg_spleen_normalised']
    x = df[feats]
    y = df['diabetes_status']
    
    model = RandomForestClassifier(n_estimators=100, max_features=3).fit(x, y)
#     model = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(x, label=y), 100)
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(x)
    break
print(np.array(shap_values).shape)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# (2, 147, 7)

# %%
# shap.force_plot(explainer.expected_value, shap_values, x)

# %%
shap.force_plot(explainer.expected_value[0], shap_values[0], x)
# Out:
# <div id='i2GI3WPYA4I1LGL1VQAID'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["output value"], "baseValue": 0.6584353741496602, "link": "identity", "featureNames": ["age", "sex", "bmi_numeric", "seg_spleen_normalised", "seg_liver_normalised", "iou_dot_seg_liver_normalised", "iou_dot_seg_spleen_normalised"], "explanations": [{"outValue": 0.9900000000000007, "simIndex": 82.0, "features": {"0": {"effect": 0.11230354227069976, "value": 48.0}, "1": {"effect": 0.014978497393098466, "value": 0.0}, "2": {"effect": 0.11540535776962331, "value": 24.12}, "3": {"effect": 0.013075989104379446, "value": 0.2434526728788622}, "4": {"effect": 0.03680801504432259, "value": 0.1637384343486849}, "5": {"effect": 0.004489193513310449, "value": 0.29571482632522506}, "6": {"effect": 0.034504030754906455, "value": 0.23730555207533147}}}, {"outValue": 0.8600000000000005, "simIndex": 99.0, "features": {"0": {"effect": 0.14992115041453183, "value": 50.0}, "1": {"effect": -0.00401764658142233, "value": 1.0}, "2": {"effect": -0.0018754236194607223, "value": 29.35}, "3": {"effect": -0.017346368823458618, "value": 0.405223148602256}, "4": {"effect": 0.018239896740745182, "value": 0.4620715944138337}, "5": {"effect": 0.04296877612533505, "value": 0.6013954275175026}, "6": {"effect": 0.01367424159406987, "value": 0.4096825109552274}}}, {"outValue": 0.9200000000000006, "simIndex": 71.0, "features": {"0": {"effect": 0.06717296421394454, "value": 57.0}, "1": {"effect": -0.009360049935262063, "value": 1.0}, "2": {"effect": 0.11852595952810509, "value": 25.85}, "3": {"effect": 0.030524507784726464, "value": 0.08881804806277586}, "4": {"effect": 0.031183788450118377, "value": 0.13788682122188722}, "5": {"effect": -0.0024017316029212835, "value": 0.2927007323634429}, "6": {"effect": 0.02591918741162919, "value": 0.11110660406966152}}}, {"outValue": 1.0000000000000007, "simIndex": 66.0, "features": {"0": {"effect": 0.11062814554749766, "value": 47.0}, "1": {"effect": 0.013633163460922552, "value": 0.0}, "2": {"effect": 0.13769217715861307, "value": 20.68}, "3": {"effect": 0.001242412558714683, "value": 0.3151299656694458}, "4": {"effect": 0.035992415376855505, "value": 0.1538423457541869}, "5": {"effect": 0.0005972116513571743, "value": 0.3027347635715748}, "6": {"effect": 0.041779100096379765, "value": 0.29220671976776974}}}, {"outValue": 0.16000000000000003, "simIndex": 136.0, "features": {"0": {"effect": -0.0702364118043369, "value": 58.0}, "1": {"effect": -0.03306081219702434, "value": 1.0}, "2": {"effect": -0.34764292454163687, "value": 36.73}, "3": {"effect": -0.04332212818845407, "value": 0.3486758214811182}, "4": {"effect": -0.02136451714731379, "value": 0.3441007133698682}, "5": {"effect": -0.00929371667932811, "value": 0.4926126037140415}, "6": {"effect": 0.026485136408433873, "value": 0.38038792547086153}}}, {"outValue": 0.7700000000000007, "simIndex": 24.0, "features": {"0": {"effect": 0.002972481817918843, "value": 60.0}, "1": {"effect": 0.05329663912089937, "value": 0.0}, "2": {"effect": -0.09532180700377588, "value": 30.83}, "3": {"effect": -0.0062147962211673, "value": 0.34693477194703287}, "4": {"effect": 0.04691005954168984, "value": 0.3241105153985911}, "5": {"effect": 0.040417913920448266, "value": 0.5020181449734035}, "6": {"effect": 0.06950413467432726, "value": 0.37307158250489525}}}, {"outValue": 0.9500000000000004, "simIndex": 103.0, "features": {"0": {"effect": 0.1796610415521295, "value": 52.0}, "1": {"effect": -0.006739053890154006, "value": 1.0}, "2": {"effect": 0.011701220192804545, "value": 28.73}, "3": {"effect": -0.0011286940747697507, "value": 0.2805787150564002}, "4": {"effect": 0.026990718929750388, "value": 0.379694948984896}, "5": {"effect": 0.03390074630992657, "value": 0.5338558856178174}, "6": {"effect": 0.047178646830652884, "value": 0.27217536973197787}}}, {"outValue": 0.9900000000000004, "simIndex": 61.0, "features": {"0": {"effect": 0.0942510153529258, "value": 51.0}, "1": {"effect": 0.016588418555692236, "value": 0.0}, "2" ...

# %%
shap.dependence_plot("sex", shap_values[1], x)

# %%
# shap.dependence_plot("bmi_numeric_normalised", shap_values[0], x)

# %%
# shap.dependence_plot("age_normalised", shap_values[0], x)

# %%
shap.dependence_plot("seg_liver_normalised", shap_values[0], x)

# %%
feats = basic_feats
dicts = {}
anova_test_dicts = {}
# basic_feats = normalised_basic_feats
for model, df in dfs_ukb.items():
#     
#     df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver'])
#     df = df.fillna(0)
    print(model)
    if 'UKB' not in model:
#         print('dataset cannot be processed!')
        continue
    if 'dataset' in model:
        continue
        
    dicts[model] = {}
    k_mod = model[4:]
    print(k_mod)
    target_col = 'diabetes_status'

#     Equation 1 process
    p_values, statsmodel, y_yp = discrete_group_feature_stats(basic_feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_csv_feats')
    dicts[model][target_col] = p_values
    dicts[model][target_col]['auc'] = auc_score
    dicts[model][target_col]['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, basic_feats, dicts, model, target_col, global_kora_models[k_mod]['normal'])
    
#     Equation 2 process
#     for organ in ['spleen', 'liver']:
    organ = 'liver'
    feats = basic_feats + [ f'seg_{organ}_normalised', f'seg_spleen_normalised']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_{organ}_seg')
    dicts[model][target_col+f'_{organ}_with_seg_volumes'] = p_values
    dicts[model][target_col+f'_{organ}_with_seg_volumes']['auc'] = auc_score
    dicts[model][target_col+f'_{organ}_with_seg_volumes']['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+f'_{organ}_with_seg_volumes', global_kora_models[k_mod][f'{organ}_seg'])


#     Equation 3 process
    feats = basic_feats + [ f'seg_{organ}_normalised', f'iou_{organ}', f'seg_spleen_normalised', f'iou_spleen']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_{organ}_seg_iou')
    dicts[model][target_col+f'_{organ}_with_seg_and_iou'] = p_values
    dicts[model][target_col+f'_{organ}_with_seg_and_iou']['auc'] = auc_score
    dicts[model][target_col+f'_{organ}_with_seg_and_iou']['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+f'_{organ}_with_seg_and_iou', global_kora_models[k_mod][f'{organ}_seg_iou'])

    feats = basic_feats + [ f'seg_{organ}_normalised',  f'seg_spleen_normalised', f'iou_dot_seg_{organ}_normalised', f'iou_dot_seg_spleen_normalised']
    p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_{organ}_seg_dot_iou')
    dicts[model][target_col+f'_{organ}_with_seg_dot_iou'] = p_values
    dicts[model][target_col+f'_{organ}_with_seg_dot_iou']['auc'] = auc_score
    dicts[model][target_col+f'_{organ}_with_seg_dot_iou']['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+f'_{organ}_with_seg_dot_iou', global_kora_models[k_mod][f'{organ}_seg_dot_iou'])


    #     Equation 4.0 process
    feats = basic_feats + [ f'seg_{organ}_normalised',  f'seg_spleen_normalised']
    p_values, statsmodel, y_yp = discrete_weighted_group_feats(df, target_col, feats, f'iou_mean')
    auc_score, f1_score = auc_roc(y_yp, f'{model}_{organ}_csv_feats')
    dicts[model][target_col+f'_{organ}_seg_reg_iou'] = p_values
    dicts[model][target_col+f'_{organ}_seg_reg_iou']['auc'] = auc_score
    dicts[model][target_col+f'_{organ}_seg_reg_iou']['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+f'_{organ}_seg_reg_iou', global_kora_models[k_mod][f'{organ}_seg_reg_iou'], 'iou_mean')
# #     Equation 4.1 process
#     feats = basic_feats + [ 'seg_spleen_normalised']
#     p_values, statsmodel = discrete_weighted_group_feats(df, target_col, feats, 'iou_spleen')
#     dicts[model][target_col+'_reg_iou_spleen'] = p_values
    
#     #     Equation 4.2 process
#     feats = basic_feats + [ 'seg_liver_normalised']
#     p_values, statsmodel = discrete_weighted_group_feats(df, target_col, feats, 'iou_liver')
#     dicts[model][target_col+'_reg_iou_liver'] = p_values

p_value_df = df_from_nested_dicts(dicts).T
p_value_df_styler = highlight_significance(p_value_df, 0.05)
p_value_df_styler
# Out:
# UKB_MC_dropout_quicknat
# MC_dropout_quicknat
# Optimization terminated successfully.
#          Current function value: 0.182250
#          Iterations 7
# UKB_MC_dropout_quicknat_csv_feats: auc_score: 0.7389245764404656
# [[15733     1]
#  [  839     1]]
# (16574, 4) (16574,) (16574, 4) (16574,)
# ensemble: auc_score: 0.615224460827931
# [[11624  4110]
#  [  427   413]]
# Optimization terminated successfully.
#          Current function value: 0.181826
#          Iterations 7
# UKB_MC_dropout_quicknat_liver_seg: auc_score: 0.7415443201559256
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6261737547440485
# [[10545  5189]
#  [  351   489]]
# Optimization terminated successfully.
#          Current function value: 0.181794
#          Iterations 7
# UKB_MC_dropout_quicknat_liver_seg_iou: auc_score: 0.7415527187104662
# [[15733     1]
#  [  839     1]]
# (16574, 8) (16574,) (16574, 8) (16574,)
# ensemble: auc_score: 0.660742886197316
# [[10228  5506]
#  [  276   564]]
# Optimization terminated successfully.
#          Current function value: 0.181746
#          Iterations 7
# UKB_MC_dropout_quicknat_liver_seg_dot_iou: auc_score: 0.7416952671496971
# [[15733     1]
#  [  839     1]]
# (16574, 8) (16574,) (16574, 8) (16574,)
# ensemble: auc_score: 0.6415128444920615
# [[11215  4519]
#  [  361   479]]
# UKB_MC_dropout_quicknat_liver_csv_feats: auc_score: 0.741497484973397
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6251824983202892
# [[10570  5164]
#  [  354   486]]
# UKB_probabilistic_quicknat
# probabilistic_quicknat
# Optimization terminated successfully.
#          Current function value: 0.182250
#          Iterations 7
# UKB_probabilistic_quicknat_csv_feats: auc_score: 0.7389245764404656
# [[15733     1]
#  [  839     1]]
# (16574, 4) (16574,) (16574, 4) (16574,)
# ensemble: auc_score: 0.6165249505166246
# [[11590  4144]
#  [  423   417]]
# Optimization terminated successfully.
#          Current function value: 0.182229
#          Iterations 7
# UKB_probabilistic_quicknat_liver_seg: auc_score: 0.739056305120243
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6184976272191857
# [[11727  4007]
#  [  427   413]]
# Optimization terminated successfully.
#          Current function value: 0.182201
#          Iterations 7
# UKB_probabilistic_quicknat_liver_seg_iou: auc_score: 0.7392913133220748
# [[15733     1]
#  [  839     1]]
# (16574, 8) (16574,) (16574, 8) (16574,)
# ensemble: auc_score: 0.6455173660922358
# [[9880 5854]
#  [ 283  557]]
# Optimization terminated successfully.
#          Current function value: 0.182206
#          Iterations 8
# UKB_probabilistic_quicknat_liver_seg_dot_iou: auc_score: 0.7390219542755452
# [[15733     1]
#  [  839     1]]
# (16574, 8) (16574,) (16574, 8) (16574,)
# ensemble: auc_score: 0.615284461312172
# [[11270  4464]
#  [  408   432]]
# UKB_probabilistic_quicknat_liver_csv_feats: auc_score: 0.7390653846386654
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6184634276997948
# [[11651  4083]
#  [  423   417]]
# UKB_hierarchical_quicknat
# hierarchical_quicknat
# Optimization terminated successfully.
#          Current function value: 0.182250
#          Iterations 7
# UKB_hierarchical_quicknat_csv_feats: auc_score: 0.7389245764404656
# [[15733     1]
#  [  839     1]]
# (16574, 4) (16574,) (16574, 4) (16574,)
# ensemble: auc_score: 0.6161924888170598
# [[11617  4117]
#  [  425   415]]
# Optimization terminated successfully.
#          Current function value: 0.182219
#          Iterations 7
# UKB_hierarchical_quicknat_liver_seg: auc_score: 0.7391606439194465
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6258556689486523
# [[11509  4225]
#  [  403   437]]
# Optimization terminated successfully.
#          Current function value: 0.182202
#          Iterations 7
# UKB_hierarchical_quicknat_liver_seg_iou: auc_score: 0.7393361056129583
# [[15733     1]
#  [  839     1]]
# (16574, 8) (16574,) (16574, 8) (16574,)
# ensemble: auc_score: 0.6636016482352443
# [[10524  5210]
#  [  287   553]]
# Optimization terminated successfully.
#          Current function value: 0.182158
#          Iterations 7
# UKB_hierarchical_quicknat_liver_seg_dot_iou: auc_score: 0.7395394868256188
# [[15733     1]
#  [  839     1]]
# (16574, 8) (16574,) (16574, 8) (16574,)
# ensemble: auc_score: 0.6335632721373792
# [[11302  4432]
#  [  379   461]]
# UKB_hierarchical_quicknat_liver_csv_feats: auc_score: 0.7391670752449957
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6267991822380408
# [[11726  4008]
#  [  413   427]]
# dataset_UKB_processed
# <style  type="text/css" >
#     #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row0_col0 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row0_col1 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row0_col5 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row0_col7 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row0_col8 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row0_col9 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row0_col23 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row1_col0 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row1_col1 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row1_col5 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row1_col7 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row1_col8 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row1_col9 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row1_col19 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row1_col22 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row1_col23 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row2_col0 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row2_col1 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row2_col5 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row2_col7 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row2_col8 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row2_col9 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row2_col19 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row2_col22 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row2_col23 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row3_col0 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row3_col1 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row3_col5 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row3_col7 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row3_col8 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row3_col9 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row3_col20 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row3_col22 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row3_col23 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col0 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col1 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col4 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col5 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col7 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col8 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col9 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col18 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col19 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col22 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row4_col23 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row5_col0 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row5_col1 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row5_col5 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row5_col7 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row5_col8 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row5_col9 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row5_col23 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row6_col0 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row6_col1 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row6_col5 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row6_col7 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row6_col8 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row6_col9 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row6_col23 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col0 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col1 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col5 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col7 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col8 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col9 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col15 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col20 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col22 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row7_col23 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row8_col0 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row8_col1 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row8_col5 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row8_col7 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row8_col8 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row8_col9 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row8_col13 {
#             background-color :  yellow;
#         }    #T_06c97b74_177e_11ea_b432_f7e2eb8f54d7row8_c

# %%
feats = basic_feats
dicts = {}
anova_test_dicts = {}
# basic_feats = normalised_basic_feats
for model, df in dfs_ukb.items():
#     
#     df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver'])
#     df = df.fillna(0)
    print(model)
    if 'UKB' not in model:
#         print('dataset cannot be processed!')
        continue
    if 'dataset' in model:
        continue
        
    dicts[model] = {}
    k_mod = model[4:]
    print(k_mod)
    target_col = 'diabetes_status'

#     Equation 1 process
    p_values, statsmodel, y_yp = discrete_group_feature_stats(basic_feats, df, target_col, ['sex'], True)
    auc_score, f1_score = auc_roc(y_yp, f'{model}_csv_feats')
    dicts[model][target_col] = p_values
    dicts[model][target_col]['auc'] = auc_score
    dicts[model][target_col]['f1'] = f1_score
    dicts, _ = aggregate_model_outputs(df, target_col, basic_feats, dicts, model, target_col, global_kora_models[k_mod]['normal'])
    
#     Equation 2 process
    for modd in [f'liver_seg', f'liver_seg_reg_iou']:
        organ = 'liver'
        feats = basic_feats + [ f'seg_{organ}_normalised', f'seg_spleen_normalised']
        p_values, statsmodel, y_yp = discrete_group_feature_stats(feats, df, target_col, ['sex'], True)
        auc_score, f1_score = auc_roc(y_yp, f'{model}_{modd}_seg')
        dicts[model][target_col+f'_{modd}_with_seg_volumes'] = p_values
        dicts[model][target_col+f'_{modd}_with_seg_volumes']['auc'] = auc_score
        dicts[model][target_col+f'_{modd}_with_seg_volumes']['f1'] = f1_score
        dicts, _ = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+f'_{modd}_with_seg_volumes', global_kora_models[k_mod][modd])


        #     Equation 4.0 process
        feats = basic_feats + [ f'seg_{organ}_normalised',  f'seg_spleen_normalised']
        p_values, statsmodel, y_yp = discrete_weighted_group_feats(df, target_col, feats, f'iou_mean')
        auc_score, f1_score = auc_roc(y_yp, f'{model}_{modd}_csv_feats')
        dicts[model][target_col+f'_{modd}_seg_reg_iou'] = p_values
        dicts[model][target_col+f'_{modd}_seg_reg_iou']['auc'] = auc_score
        dicts[model][target_col+f'_{modd}_seg_reg_iou']['f1'] = f1_score
        dicts, _ = aggregate_model_outputs(df, target_col, feats, dicts, model, target_col+f'_{modd}_seg_reg_iou', global_kora_models[k_mod][modd])
# #     Equation 4.1 process
#     feats = basic_feats + [ 'seg_spleen_normalised']
#     p_values, statsmodel = discrete_weighted_group_feats(df, target_col, feats, 'iou_spleen')
#     dicts[model][target_col+'_reg_iou_spleen'] = p_values
    
#     #     Equation 4.2 process
#     feats = basic_feats + [ 'seg_liver_normalised']
#     p_values, statsmodel = discrete_weighted_group_feats(df, target_col, feats, 'iou_liver')
#     dicts[model][target_col+'_reg_iou_liver'] = p_values

p_value_df = df_from_nested_dicts(dicts).T
p_value_df_styler = highlight_significance(p_value_df, 0.05)
p_value_df_styler
# Out:
# UKB_MC_dropout_quicknat
# MC_dropout_quicknat
# Optimization terminated successfully.
#          Current function value: 0.182250
#          Iterations 7
# UKB_MC_dropout_quicknat_csv_feats: auc_score: 0.7389245764404656
# [[15733     1]
#  [  839     1]]
# (16574, 4) (16574,) (16574, 4) (16574,)
# ensemble: auc_score: 0.615224460827931
# [[11624  4110]
#  [  427   413]]
# Optimization terminated successfully.
#          Current function value: 0.181826
#          Iterations 7
# UKB_MC_dropout_quicknat_liver_seg_seg: auc_score: 0.7415443201559256
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6261737547440485
# [[10545  5189]
#  [  351   489]]
# UKB_MC_dropout_quicknat_liver_seg_csv_feats: auc_score: 0.741497484973397
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6261737547440485
# [[10545  5189]
#  [  351   489]]
# Optimization terminated successfully.
#          Current function value: 0.181826
#          Iterations 7
# UKB_MC_dropout_quicknat_liver_seg_reg_iou_seg: auc_score: 0.7415443201559256
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6251824983202892
# [[10570  5164]
#  [  354   486]]
# UKB_MC_dropout_quicknat_liver_seg_reg_iou_csv_feats: auc_score: 0.741497484973397
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6251824983202892
# [[10570  5164]
#  [  354   486]]
# UKB_probabilistic_quicknat
# probabilistic_quicknat
# Optimization terminated successfully.
#          Current function value: 0.182250
#          Iterations 7
# UKB_probabilistic_quicknat_csv_feats: auc_score: 0.7389245764404656
# [[15733     1]
#  [  839     1]]
# (16574, 4) (16574,) (16574, 4) (16574,)
# ensemble: auc_score: 0.6165249505166246
# [[11590  4144]
#  [  423   417]]
# Optimization terminated successfully.
#          Current function value: 0.182229
#          Iterations 7
# UKB_probabilistic_quicknat_liver_seg_seg: auc_score: 0.739056305120243
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6184976272191857
# [[11727  4007]
#  [  427   413]]
# UKB_probabilistic_quicknat_liver_seg_csv_feats: auc_score: 0.7390653846386654
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6184976272191857
# [[11727  4007]
#  [  427   413]]
# Optimization terminated successfully.
#          Current function value: 0.182229
#          Iterations 7
# UKB_probabilistic_quicknat_liver_seg_reg_iou_seg: auc_score: 0.739056305120243
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6184634276997948
# [[11651  4083]
#  [  423   417]]
# UKB_probabilistic_quicknat_liver_seg_reg_iou_csv_feats: auc_score: 0.7390653846386654
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6184634276997948
# [[11651  4083]
#  [  423   417]]
# UKB_hierarchical_quicknat
# hierarchical_quicknat
# Optimization terminated successfully.
#          Current function value: 0.182250
#          Iterations 7
# UKB_hierarchical_quicknat_csv_feats: auc_score: 0.7389245764404656
# [[15733     1]
#  [  839     1]]
# (16574, 4) (16574,) (16574, 4) (16574,)
# ensemble: auc_score: 0.6161924888170598
# [[11617  4117]
#  [  425   415]]
# Optimization terminated successfully.
#          Current function value: 0.182219
#          Iterations 7
# UKB_hierarchical_quicknat_liver_seg_seg: auc_score: 0.7391606439194465
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6258556689486523
# [[11509  4225]
#  [  403   437]]
# UKB_hierarchical_quicknat_liver_seg_csv_feats: auc_score: 0.7391670752449957
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6258556689486523
# [[11509  4225]
#  [  403   437]]
# Optimization terminated successfully.
#          Current function value: 0.182219
#          Iterations 7
# UKB_hierarchical_quicknat_liver_seg_reg_iou_seg: auc_score: 0.7391606439194465
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6267991822380408
# [[11726  4008]
#  [  413   427]]
# UKB_hierarchical_quicknat_liver_seg_reg_iou_csv_feats: auc_score: 0.7391670752449957
# [[15733     1]
#  [  839     1]]
# (16574, 6) (16574,) (16574, 6) (16574,)
# ensemble: auc_score: 0.6267991822380408
# [[11726  4008]
#  [  413   427]]
# dataset_UKB_processed
# <style  type="text/css" >
#     #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row0_col0 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row0_col1 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row0_col5 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row0_col7 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row0_col8 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row0_col9 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row0_col15 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row0_col17 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col0 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col1 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col5 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col7 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col8 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col9 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col11 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col14 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col15 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row1_col17 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col0 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col1 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col4 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col5 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col7 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col8 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col9 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col10 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col11 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col14 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col15 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row2_col17 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col0 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col1 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col5 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col7 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col8 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col9 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col11 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col14 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col15 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row3_col17 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col0 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col1 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col4 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col5 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col7 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col8 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col9 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col10 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col11 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col14 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col15 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row4_col17 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row5_col0 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row5_col1 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row5_col5 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row5_col7 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row5_col8 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row5_col9 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row5_col15 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row5_col17 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row6_col0 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row6_col1 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row6_col5 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row6_col7 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row6_col8 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row6_col9 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row6_col15 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row6_col17 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row7_col0 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row7_col1 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row7_col4 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row7_col5 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row7_col7 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row7_col8 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row7_col9 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7row7_col10 {
#             background-color :  yellow;
#         }    #T_018ba954_177c_11ea_b432_f7e2eb8f54d7ro

# %%
p_value_df['voting_auc'].plot()

# %% [markdown]
# # Regularised Group Feats (eq 4)

# %%
feats = basic_feats
dicts = {}
anova_test_dicts = {}
for model, df in dfs.items():
#     
#     df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver'])
#     df = df.fillna(0)

        
    dicts[model] = {}
    target_cols = ['seg_spleen_normalised', 'seg_liver_normalised']
    for target_col in target_cols:
#     #     Equation 1 process
#         feats_string = make_feature_string(basic_feats, ['sex', 'diabetes_status'])
#         p_values, statsmodel = normal_group_fit(df, target_col, feats_string)
#         dicts[model][target_col] = p_values

    #     Equation 2 process
        feats = basic_feats + ['diabetes_status']
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = normal_group_fit(df, target_col, feats_string)
        regression_plot(y_yp, f'{model}_{target_col}_csv-feats')
        dicts[model][target_col+'_with_csv_feats'] = p_values

        if 'dataset' in model:
#             print('dataset cannot be processed!')
            continue
    
    #     Equation 3 process
        if target_col == 'seg_spleen_normalised':
            iou_feat = ['iou_spleen']
        else:
            iou_feat = ['iou_liver']
        feats = basic_feats + [ 'diabetes_status'] + iou_feat
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = normal_group_fit(df, target_col, feats_string)
        regression_plot(y_yp, f'{model}_{target_col}_seg_iou')
        dicts[model][target_col+'_with_seg_and_iou'] = p_values

    #     Equation 4 process
        feats = basic_feats + [ 'diabetes_status']
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = weighted_group_feats(df, target_col, feats_string, iou_feat[0])
        regression_plot(y_yp, f'{model}_{target_col}_seg_reg_iou')
        dicts[model][target_col+'_with_regularised_seg_volumes'] = p_values

p_value_df = df_from_nested_dicts(dicts).T
p_value_df.to_csv('to_seg.csv')
p_value_df_styler = highlight_significance(p_value_df, 0.05)
p_value_df_styler
# Out:
# full_bayesian_0dot01_seg_spleen_normalised_csv-feats
# full_bayesian_0dot01_seg_spleen_normalised_seg_iou
# full_bayesian_0dot01_seg_spleen_normalised_seg_reg_iou
# full_bayesian_0dot01_seg_liver_normalised_csv-feats
# full_bayesian_0dot01_seg_liver_normalised_seg_iou
# full_bayesian_0dot01_seg_liver_normalised_seg_reg_iou
# MC_dropout_quicknat_seg_spleen_normalised_csv-feats
# MC_dropout_quicknat_seg_spleen_normalised_seg_iou
# MC_dropout_quicknat_seg_spleen_normalised_seg_reg_iou
# MC_dropout_quicknat_seg_liver_normalised_csv-feats
# MC_dropout_quicknat_seg_liver_normalised_seg_iou
# MC_dropout_quicknat_seg_liver_normalised_seg_reg_iou
# probabilistic_quicknat_seg_spleen_normalised_csv-feats
# probabilistic_quicknat_seg_spleen_normalised_seg_iou
# probabilistic_quicknat_seg_spleen_normalised_seg_reg_iou
# probabilistic_quicknat_seg_liver_normalised_csv-feats
# probabilistic_quicknat_seg_liver_normalised_seg_iou
# probabilistic_quicknat_seg_liver_normalised_seg_reg_iou
# hierarchical_quicknat_seg_spleen_normalised_csv-feats
# hierarchical_quicknat_seg_spleen_normalised_seg_iou
# hierarchical_quicknat_seg_spleen_normalised_seg_reg_iou
# hierarchical_quicknat_seg_liver_normalised_csv-feats
# hierarchical_quicknat_seg_liver_normalised_seg_iou
# hierarchical_quicknat_seg_liver_normalised_seg_reg_iou
# dataset_KORA_processed_seg_spleen_normalised_csv-feats
# dataset_KORA_processed_seg_liver_normalised_csv-feats
# <style  type="text/css" >
#     #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row0_col1 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row0_col2 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row0_col6 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row0_col7 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row0_col8 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row0_col9 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row0_col10 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row0_col11 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col1 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col2 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col5 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col6 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col7 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col8 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col9 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col10 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col11 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row1_col14 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row2_col1 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row2_col2 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row2_col6 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row2_col7 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row2_col8 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row2_col9 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row2_col10 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row2_col11 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row3_col1 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row3_col2 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row3_col6 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row3_col7 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row3_col8 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row3_col9 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row3_col10 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row3_col11 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col0 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col2 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col5 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col6 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col7 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col8 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col9 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col10 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col11 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row4_col12 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row5_col0 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row5_col1 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row5_col2 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row5_col6 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row5_col7 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row5_col8 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row5_col9 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row5_col10 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row5_col11 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row6_col1 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row6_col2 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row6_col5 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row6_col7 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row6_col8 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row6_col9 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row6_col10 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row6_col11 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col1 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col2 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col4 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col5 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col7 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col8 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col9 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col10 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col11 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row7_col14 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row8_col1 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row8_col2 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row8_col5 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row8_col7 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row8_col8 {
#             background-color :  yellow;
#         }    #T_0545ac48_177c_11ea_b432_f7e2eb8f54d7row8_col

# %%
feats = basic_feats
dicts = {}
anova_test_dicts = {}
for model, df in dfs_ukb.items():
#     
#     df, normalised_cols = z_score_column_normalise(df, ['seg_spleen', 'seg_liver'])
#     df = df.fillna(0)

    

    if 'UKB' not in model:
#         print('dataset cannot be processed!')
        continue
        
    dicts[model] = {}
    target_cols = ['seg_spleen_normalised', 'seg_liver_normalised']
    for target_col in target_cols:
    #     Equation 1 process
        feats = basic_feats + ['diabetes_status']
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = normal_group_fit(df, target_col, feats_string)
        regression_plot(y_yp, f'{model}_{target_col}')
        dicts[model][target_col] = p_values

#     #     Equation 2 process
#         feats = basic_feats + ['diabetes_status']
#         feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
#         p_values, statsmodel = normal_group_fit(df, target_col, feats_string)
#         dicts[model][target_col+'_with_seg_volumes'] = p_values

    #     Equation 3 process
        if 'dataset' in model:
            print('dataset cannot be processed!')
            continue
        if target_col == 'seg_spleen_normalised':
            iou_feat = ['iou_spleen']
        else:
            iou_feat = ['iou_liver']
        feats = basic_feats + [ 'diabetes_status'] + iou_feat
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = normal_group_fit(df, target_col, feats_string)
        regression_plot(y_yp, f'{model}_{target_col}_seg_iou')
        dicts[model][target_col+'_with_iou'] = p_values

    #     Equation 4 process
        feats = basic_feats + [ 'diabetes_status']
        feats_string = make_feature_string(feats, ['sex', 'diabetes_status'])
        p_values, statsmodel, y_yp = weighted_group_feats(df, target_col, feats_string, iou_feat[0])
        regression_plot(y_yp, f'{model}_{target_col}_seg_reg_iou')
        dicts[model][target_col+'_with_regularised_seg_volumes'] = p_values

p_value_df = df_from_nested_dicts(dicts).T
p_value_df.to_csv('to_seg.csv')
p_value_df_styler = highlight_significance(p_value_df, 0.05)
p_value_df_styler
# Out:
# UKB_MC_dropout_quicknat_seg_spleen_normalised
# UKB_MC_dropout_quicknat_seg_spleen_normalised_seg_iou
# UKB_MC_dropout_quicknat_seg_spleen_normalised_seg_reg_iou
# UKB_MC_dropout_quicknat_seg_liver_normalised
# UKB_MC_dropout_quicknat_seg_liver_normalised_seg_iou
# UKB_MC_dropout_quicknat_seg_liver_normalised_seg_reg_iou
# UKB_probabilistic_quicknat_seg_spleen_normalised
# UKB_probabilistic_quicknat_seg_spleen_normalised_seg_iou
# UKB_probabilistic_quicknat_seg_spleen_normalised_seg_reg_iou
# UKB_probabilistic_quicknat_seg_liver_normalised
# UKB_probabilistic_quicknat_seg_liver_normalised_seg_iou
# UKB_probabilistic_quicknat_seg_liver_normalised_seg_reg_iou
# UKB_hierarchical_quicknat_seg_spleen_normalised
# UKB_hierarchical_quicknat_seg_spleen_normalised_seg_iou
# UKB_hierarchical_quicknat_seg_spleen_normalised_seg_reg_iou
# UKB_hierarchical_quicknat_seg_liver_normalised
# UKB_hierarchical_quicknat_seg_liver_normalised_seg_iou
# UKB_hierarchical_quicknat_seg_liver_normalised_seg_reg_iou
# dataset_UKB_processed_seg_spleen_normalised
# dataset cannot be processed!
# dataset_UKB_processed_seg_liver_normalised
# dataset cannot be processed!
# <style  type="text/css" >
#     #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col1 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col2 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col3 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col4 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col6 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col7 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col8 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col9 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col10 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col11 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row0_col16 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col1 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col2 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col3 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col5 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col6 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col7 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col8 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col9 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col10 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col11 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row1_col14 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col1 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col2 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col3 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col4 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col6 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col7 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col8 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col9 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col10 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col11 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row2_col16 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col0 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col1 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col2 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col3 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col4 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col6 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col7 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col8 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col9 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col10 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col11 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row3_col16 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col0 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col1 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col2 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col3 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col4 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col6 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col7 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col8 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col9 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col10 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col11 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col12 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row4_col16 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col0 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col1 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col2 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col3 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col4 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col6 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col7 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col8 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col9 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col10 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col11 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row5_col16 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row6_col1 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row6_col3 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row6_col4 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row6_col7 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row6_col8 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row6_col9 {
#             background-color :  yellow;
#         }    #T_0a70a740_177c_11ea_b432_f7e2eb8f54d7row6_col
